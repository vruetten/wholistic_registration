# %% [markdown]
# ## F260517 Registration — Forward-Only Pipeline (First-5-Frames Warmup)
#
# zRatio = 10, frame_rate = 4.07066 s/frame, z_window = 4.0

# %%
import cupy as cp
cp.cuda.Device(1).use()
import os
os.chdir('/home/cyf/wbi/Virginia/code/wbi_0123/wholistic_registration/src/wholistic_registration')
from utils import IO
from utils import calFlowCrossResolution, calFlow3d_Wei_v1
from utils import registration
from utils import option
from utils import preprocess as prep
from utils import mask
from utils import visualization
import sys
from pathlib import Path

PROJECT_ROOT = Path("/home/cyf/wbi/Virginia/code/CoarseFlow").resolve()
sys.path.insert(0, str(PROJECT_ROOT))

from training.inference import (
    CoarseFlowInferenceConfig,
    CoarseFlowPredictor,
)

F260517_mov_path = "/home/cyf/wbi/Virginia/raw_data/f260517/260517_exp_00001_TZCYX.ome.tiff"
F260517_ref_path = "/home/cyf/wbi/Virginia/raw_data/f260517/260517_anat_00003_TZCYX.ome.tiff"

import numpy as np
import pandas as pd
from scipy.ndimage import distance_transform_edt, map_coordinates, maximum_filter
from importlib import reload
from typing import Any
from collections import deque
from numpy import ndarray

print("Imports done.")
# Out:
# Imports done.

# %%
# =========================================================
# Helper functions (single copy, no duplicates)
# =========================================================

def update_reference_intensity_mapping_from_target_stack(
    F260517_ref_mem,
    target_stack_zyx,
    z_idx,
    option,
    thresFactor,
    maskRange,
    smoothPenalty_raw,
    percentiles,
):
    """
    Learn raw reference -> target intensity mapping using only z_idx planes,
    then apply the learned mapping to the full reference volume.

    F260517_ref_mem:
        Raw reference membrane volume, shape (Zref, Y, X).

    target_stack_zyx:
        Target stack used for learning intensity mapping, shape (K, Y, X).

        Initial update:
            target_stack_zyx = raw moving frame 0, F260517_mov_mem[0].

        Later updates:
            target_stack_zyx = previous/recent registered membrane image,
            i.e. mem_mapped.transpose(2, 1, 0).

    z_idx:
        Reference z planes corresponding to moving slices, shape (K,).

    Returns
    -------
    F260517_ref_mem_adj:
        Adjusted full reference volume, shape (X, Y, Zref).

    src_q, tgt_q, used_percentiles:
        Quantile mapping information.
    """

    target_stack_zyx = np.asarray(target_stack_zyx, dtype=np.float32)

    if target_stack_zyx.ndim != 3:
        raise ValueError(
            f"target_stack_zyx should be (K,Y,X), got {target_stack_zyx.shape}"
        )

    if target_stack_zyx.shape[0] != len(z_idx):
        raise ValueError(
            f"target_stack_zyx K={target_stack_zyx.shape[0]} does not match "
            f"z_idx length={len(z_idx)}"
        )

    # ------------------------------------------------------------
    # 1. Learn mapping only on matched planes.
    # ------------------------------------------------------------
    ref_source_zyx = F260517_ref_mem[z_idx].astype(np.float32, copy=False)

    if ref_source_zyx.shape != target_stack_zyx.shape:
        raise ValueError(
            f"ref_source_zyx shape {ref_source_zyx.shape} does not match "
            f"target_stack_zyx shape {target_stack_zyx.shape}"
        )

    src_q, tgt_q, used_percentiles = prep.learn_quantile_mapping(
        source=ref_source_zyx,
        target=target_stack_zyx,
        percentiles=percentiles,
    )

    # ------------------------------------------------------------
    # 2. Apply learned mapping to the full reference volume.
    # ------------------------------------------------------------
    F260517_ref_mem_adj = prep.apply_quantile_mapping(
        F260517_ref_mem,
        src_q,
        tgt_q,
    ).transpose(2, 1, 0).astype(np.float32, copy=False)  # (X, Y, Zref)

    # ------------------------------------------------------------
    # 3. Update reference mask and smooth penalty.
    # ------------------------------------------------------------
    option["mask_ref"] = mask.getMask(F260517_ref_mem_adj, thresFactor)
    option["mask_ref"] = mask.bwareafilt3_wei(option["mask_ref"], maskRange)

    Pnltfactor = prep.getSmPnltNormFctr(F260517_ref_mem_adj, option)
    option["smoothPenalty"] = Pnltfactor * smoothPenalty_raw

    return F260517_ref_mem_adj, src_q, tgt_q, used_percentiles




def robust_average_target_z(target_z_list, method="median", trim_percentiles=(10, 90)):
    """
    Combine target_z estimates from multiple warmup frames.

    target_z_list:
        list of arrays, each shape (K,)

    return:
        fixed_target_z, shape (K,)
    """
    arr = np.stack([np.asarray(z, dtype=np.float32) for z in target_z_list], axis=0)

    if method == "median":
        fixed_z = np.nanmedian(arr, axis=0)

    elif method == "mean":
        fixed_z = np.nanmean(arr, axis=0)

    elif method == "trimmed_mean":
        lo_p, hi_p = trim_percentiles
        fixed = []

        for k_idx in range(arr.shape[1]):
            vals = arr[:, k_idx]
            vals = vals[np.isfinite(vals)]

            if vals.size == 0:
                fixed.append(np.nan)
                continue

            lo = np.percentile(vals, lo_p)
            hi = np.percentile(vals, hi_p)
            vals_trim = vals[(vals >= lo) & (vals <= hi)]

            if vals_trim.size == 0:
                fixed.append(float(np.median(vals)))
            else:
                fixed.append(float(np.mean(vals_trim)))

        fixed_z = np.asarray(fixed, dtype=np.float32)

    else:
        raise ValueError("method should be 'median', 'mean', or 'trimmed_mean'.")

    return fixed_z.astype(np.float32)


def estimate_projection_z_from_phase_simple(
    phase_new,
    z_init,
    ref_shape,
    ref_volume_order="zyx",
    method="trimmed_mean",
    trim_percentiles=(5, 95),
    frame_idx=None,
):
    """
    Estimate one target reference z plane for each moving slice k
    from phase_new[..., 2].

    phase_new:
        shape (X, Y, K, 3), xyz coordinates in reference volume

    z_init:
        shape (K,)

    ref_shape:
        if ref_volume_order == "zyx": (Zref, Yref, Xref)
        if ref_volume_order == "xyz": (Xref, Yref, Zref)
    """
    if hasattr(phase_new, "get"):
        phase = phase_new.get()
    else:
        phase = np.asarray(phase_new)

    phase = np.asarray(phase, dtype=np.float32)
    z_init = np.asarray(z_init, dtype=np.float32)

    if phase.ndim != 4 or phase.shape[-1] != 3:
        raise ValueError(f"phase_new should be (X,Y,K,3), got {phase.shape}")

    X, Y, K_local, _ = phase.shape

    if len(z_init) != K_local:
        raise ValueError(f"z_init length {len(z_init)} does not match K={K_local}")

    x_ref = phase[..., 0]
    y_ref = phase[..., 1]
    z_ref = phase[..., 2]

    if ref_volume_order == "zyx":
        Zref, Yref, Xref = ref_shape
    elif ref_volume_order == "xyz":
        Xref, Yref, Zref = ref_shape
    else:
        raise ValueError("ref_volume_order should be 'zyx' or 'xyz'.")

    valid = (
        np.isfinite(x_ref)
        & np.isfinite(y_ref)
        & np.isfinite(z_ref)
        & (x_ref >= 0) & (x_ref <= Xref - 1)
        & (y_ref >= 0) & (y_ref <= Yref - 1)
        & (z_ref >= 0) & (z_ref <= Zref - 1)
    )

    target_z_pred = np.zeros(K_local, dtype=np.float32)
    rows = []

    for k_idx in range(K_local):
        z_k = z_ref[:, :, k_idx]
        valid_k = valid[:, :, k_idx]
        z_valid = z_k[valid_k]

        if z_valid.size == 0:
            z_est = float(z_init[k_idx])

        else:
            if method == "mean":
                z_est = float(np.mean(z_valid))

            elif method == "median":
                z_est = float(np.median(z_valid))

            elif method == "trimmed_mean":
                p_low, p_high = trim_percentiles
                lo = np.percentile(z_valid, p_low)
                hi = np.percentile(z_valid, p_high)
                z_trim = z_valid[(z_valid >= lo) & (z_valid <= hi)]

                if z_trim.size == 0:
                    z_est = float(np.median(z_valid))
                else:
                    z_est = float(np.mean(z_trim))

            else:
                raise ValueError("method should be 'mean', 'median', or 'trimmed_mean'.")

        target_z_pred[k_idx] = z_est

        if z_valid.size > 0:
            dz_valid = z_valid - float(z_init[k_idx])

            rows.append({
                "frame": frame_idx,
                "k": k_idx,
                "z_init": float(z_init[k_idx]),
                "target_z_pred": float(z_est),
                "target_minus_z_init": float(z_est - z_init[k_idx]),
                "z_mean": float(np.mean(z_valid)),
                "z_median": float(np.median(z_valid)),
                "z_p05": float(np.percentile(z_valid, 5)),
                "z_p95": float(np.percentile(z_valid, 95)),
                "dz_mean": float(np.mean(dz_valid)),
                "dz_median": float(np.median(dz_valid)),
                "dz_p05": float(np.percentile(dz_valid, 5)),
                "dz_p95": float(np.percentile(dz_valid, 95)),
                "valid_ratio": float(z_valid.size / (X * Y)),
            })

        else:
            rows.append({
                "frame": frame_idx,
                "k": k_idx,
                "z_init": float(z_init[k_idx]),
                "target_z_pred": float(z_est),
                "target_minus_z_init": float(z_est - z_init[k_idx]),
                "z_mean": np.nan,
                "z_median": np.nan,
                "z_p05": np.nan,
                "z_p95": np.nan,
                "dz_mean": np.nan,
                "dz_median": np.nan,
                "dz_p05": np.nan,
                "dz_p95": np.nan,
                "valid_ratio": 0.0,
            })

    return target_z_pred, pd.DataFrame(rows)


# =========================================================
# Supersurface / surface supersampling helpers
# =========================================================


def _make_xy_sampling_grid(X, Y, upsample_factor):
    """
    Build a dense sampling grid in moving XY parameter domain.

    Original grid:
        x = 0, 1, ..., X-1
        y = 0, 1, ..., Y-1

    Upsampled grid covers the same coordinate range [0, X-1] and [0, Y-1].
    """
    factor = int(upsample_factor)

    if factor < 1:
        raise ValueError("upsample_factor should be >= 1.")

    Xup = int(X * factor)
    Yup = int(Y * factor)

    x_new = np.linspace(0, X - 1, Xup, dtype=np.float32)
    y_new = np.linspace(0, Y - 1, Yup, dtype=np.float32)

    Xg, Yg = np.meshgrid(x_new, y_new, indexing="ij")

    coords_2d = np.vstack([
        Xg.reshape(-1),
        Yg.reshape(-1),
    ])

    return coords_2d, Xup, Yup


def upsample_phase_xy_for_supersurface(
    phase_new,
    upsample_factor=2,
):
    """
    Upsample phase_new in moving XY parameter domain.

    phase_new:
        shape (X, Y, K, 3)

    output:
        shape (X*factor, Y*factor, K, 3)

    This is a practical approximation to sampling a continuous moving surface.
    """
    phase = np.asarray(phase_new, dtype=np.float32)

    if phase.ndim != 4 or phase.shape[-1] != 3:
        raise ValueError(f"phase_new should be (X,Y,K,3), got {phase.shape}")

    factor = int(upsample_factor)

    if factor == 1:
        return phase

    X, Y, K_local, C = phase.shape
    coords_2d, Xup, Yup = _make_xy_sampling_grid(X, Y, factor)

    phase_up = np.empty((Xup, Yup, K_local, C), dtype=np.float32)

    for k_idx in range(K_local):
        for c_idx in range(C):
            phase_up[:, :, k_idx, c_idx] = map_coordinates(
                phase[:, :, k_idx, c_idx],
                coords_2d,
                order=1,
                mode="nearest",
            ).reshape(Xup, Yup)

    return phase_up




def upsample_values_xy_for_supersurface(
    values_xyk,
    upsample_factor=2,
    order=1,
):
    """
    Upsample values in moving XY parameter domain.

    values_xyk:
        shape (X, Y, K)

    order:
        1: bilinear-like interpolation, suitable for membrane.
        0: nearest interpolation, suitable for sparse bright signal.
    """
    values = np.asarray(values_xyk, dtype=np.float32)

    if values.ndim != 3:
        raise ValueError(f"values_xyk should be (X,Y,K), got {values.shape}")

    factor = int(upsample_factor)

    if factor == 1:
        return values

    X, Y, K_local = values.shape
    coords_2d, Xup, Yup = _make_xy_sampling_grid(X, Y, factor)

    values_up = np.empty((Xup, Yup, K_local), dtype=np.float32)

    for k_idx in range(K_local):
        values_up[:, :, k_idx] = map_coordinates(
            values[:, :, k_idx],
            coords_2d,
            order=order,
            mode="nearest",
        ).reshape(Xup, Yup)

    return values_up


# =========================================================
# Output / diagnostics helpers
# =========================================================


def save_single_channel_ome_tiff(
    volume_zyx,
    out_dir,
    frame_idx,
    label="F260517",
):
    """
    Save one volume as a single-channel OME-TIFF in one output folder.

    volume_zyx:
        shape (Z, Y, X)
    """
    os.makedirs(out_dir, exist_ok=True)

    IO.write_multichannel_volume_as_ome_tiff(
        volume=[np.asarray(volume_zyx, dtype=np.float32)],
        out_dir=out_dir,
        frame_idx=frame_idx,
        label=label,
    )




def summarize_coverage_only(
    frame_idx,
    coverage,
    coverage_threshold=0.0,
):
    """
    Summarize coverage map statistics.

    coverage:
        shape (Nplanes, Y, X)

    coverage <= threshold is treated as no coverage.
    """
    coverage = np.asarray(coverage, dtype=np.float32)

    if coverage.ndim != 3:
        raise ValueError(f"coverage should be (Nplanes,Y,X), got {coverage.shape}")

    no_coverage = coverage <= coverage_threshold

    no_cov_per_plane = np.mean(no_coverage, axis=(1, 2))
    cov_mean_per_plane = np.mean(coverage, axis=(1, 2))
    cov_max_per_plane = np.max(coverage, axis=(1, 2))

    global_no_cov = float(np.mean(no_coverage))
    worst_k = int(np.argmax(no_cov_per_plane))

    print(
        f"[Coverage] frame {frame_idx}: "
        f"global_no_cov={global_no_cov:.4f}, "
        f"min_plane_no_cov={float(no_cov_per_plane.min()):.4f}, "
        f"median_plane_no_cov={float(np.median(no_cov_per_plane)):.4f}, "
        f"max_plane_no_cov={float(no_cov_per_plane.max()):.4f}, "
        f"worst_k={worst_k}"
    )

    rows = []

    rows.append({
        "frame": int(frame_idx),
        "plane": -1,
        "is_global": True,
        "no_coverage_ratio": global_no_cov,
        "coverage_ratio": 1.0 - global_no_cov,
        "coverage_mean": float(np.mean(coverage)),
        "coverage_max": float(np.max(coverage)),
        "worst_plane_by_no_coverage": worst_k,
        "max_plane_no_coverage_ratio": float(no_cov_per_plane.max()),
    })

    for k_idx in range(coverage.shape[0]):
        rows.append({
            "frame": int(frame_idx),
            "plane": int(k_idx),
            "is_global": False,
            "no_coverage_ratio": float(no_cov_per_plane[k_idx]),
            "coverage_ratio": float(1.0 - no_cov_per_plane[k_idx]),
            "coverage_mean": float(cov_mean_per_plane[k_idx]),
            "coverage_max": float(cov_max_per_plane[k_idx]),
            "worst_plane_by_no_coverage": worst_k,
            "max_plane_no_coverage_ratio": float(no_cov_per_plane.max()),
        })

    return rows




def fill_holes_nearest_limited(
    proj_zyx,
    fill_value=-200.0,
    max_fill_distance=2.0,
    hole_tol=1e-6,
):
    """
    Fill only small holes using nearest valid pixels.

    This function does NOT smooth the whole image.
    It only modifies pixels equal to fill_value.

    proj_zyx:
        shape (Z, Y, X)

    max_fill_distance:
        Only holes within this distance from valid pixels are filled.
    """
    proj = np.asarray(proj_zyx, dtype=np.float32)
    out = proj.copy()

    for zi in range(out.shape[0]):
        plane = out[zi]

        hole = np.abs(plane - fill_value) <= hole_tol
        valid = (~hole) & np.isfinite(plane)

        if not np.any(hole) or not np.any(valid):
            continue

        dist, indices = distance_transform_edt(
            ~valid,
            return_indices=True,
        )

        fill_mask = hole & (dist <= max_fill_distance)

        nearest_y = indices[0][fill_mask]
        nearest_x = indices[1][fill_mask]

        plane[fill_mask] = plane[nearest_y, nearest_x]
        out[zi] = plane

    return out




def project_converge_map_gpu(
    phase_new,
    ref_volume_for_shape,
    fixed_target_z,
    ref_volume_order="xyz",
    z_window=3.0,
    downsample_xy=1,
    xy_extra_radius=0,
):
    """
    Return coverage map for current phase_new.

    Output:
        coverage_zyx, shape (Nplanes, Y, X)
        value > 0 means at least one sample hit this pixel.
    """
    values_ones = np.ones(phase_new.shape[:-1], dtype=np.float32)

    coverage = calFlowCrossResolution.project_coords_to_fixed_planes_gpu(
        coords_ref_xyk_xyz=phase_new,
        ref_volume=ref_volume_for_shape,
        target_z_planes=fixed_target_z,
        values_xyk=values_ones,
        ref_volume_order=ref_volume_order,
        z_window=z_window,
        downsample_xy=downsample_xy,
        fill_value=0.0,
        return_numpy=True,
        output_order="zyx",
        xy_splat_mode="subpixel_footprint",
        xy_extra_radius=xy_extra_radius,
    )

    return coverage



def project_and_save_single_frame_moving_derived(
    frame_idx,
    phase_new,
    fixed_target_z,
    ref_mem_adj_for_projection,
    F260517_ref_sparseCell,
    raw_mem_zyx,
    raw_sparseCell_zyx,
    out_dirs,
    surface_upsample_factor=2,
    surface_mem_value_order=1,
    surface_sparse_value_order=0,
    enable_coverage_diagnostics=True,
    coverage_threshold=0.0,
    enable_hole_filling=False,
):
    """
    Save four outputs into four separate folders:

        1. raw moving membrane
        2. raw moving sparse-cell
        3. projected moving membrane
        4. projected moving sparse-cell

    Projected values come from current raw moving images, not reference:

        values_xyk = raw_mem_zyx.transpose(2, 1, 0)
        values_xyk = raw_sparseCell_zyx.transpose(2, 1, 0)

    Supersurface:
        If surface_upsample_factor > 1, phase_new and moving values are
        upsampled in moving XY parameter domain before projection.
    """
    phase_new = np.asarray(phase_new, dtype=np.float32)

    raw_mem_zyx = np.asarray(raw_mem_zyx, dtype=np.float32)
    raw_sparseCell_zyx = np.asarray(raw_sparseCell_zyx, dtype=np.float32)

    raw_mem_xyk = raw_mem_zyx.transpose(2, 1, 0).astype(np.float32, copy=False)
    raw_sparse_xyk = raw_sparseCell_zyx.transpose(2, 1, 0).astype(np.float32, copy=False)

    # ------------------------------------------------------------
    # 1. Save raw moving channels
    # ------------------------------------------------------------
    save_single_channel_ome_tiff(
        volume_zyx=raw_mem_zyx,
        out_dir=out_dirs["raw_moving_mem"],
        frame_idx=frame_idx,
        label="F260517_raw_mem",
    )

    save_single_channel_ome_tiff(
        volume_zyx=raw_sparseCell_zyx,
        out_dir=out_dirs["raw_moving_sparseCell"],
        frame_idx=frame_idx,
        label="F260517_raw_sparseCell",
    )

    # ------------------------------------------------------------
    # 2. Supersurface sampling
    # ------------------------------------------------------------
    if int(surface_upsample_factor) > 1:
        print(
            f"[Supersurface] frame {frame_idx}: "
            f"upsample_factor={surface_upsample_factor}"
        )

    phase_for_projection = upsample_phase_xy_for_supersurface(
        phase_new,
        upsample_factor=surface_upsample_factor,
    )

    mem_values_for_projection = upsample_values_xy_for_supersurface(
        raw_mem_xyk,
        upsample_factor=surface_upsample_factor,
        order=surface_mem_value_order,
    )

    sparse_values_for_projection = upsample_values_xy_for_supersurface(
        raw_sparse_xyk,
        upsample_factor=surface_upsample_factor,
        order=surface_sparse_value_order,
    )

    if phase_for_projection.shape[:-1] != mem_values_for_projection.shape:
        raise ValueError(
            f"phase_for_projection shape {phase_for_projection.shape[:-1]} "
            f"does not match mem_values_for_projection shape {mem_values_for_projection.shape}"
        )

    if phase_for_projection.shape[:-1] != sparse_values_for_projection.shape:
        raise ValueError(
            f"phase_for_projection shape {phase_for_projection.shape[:-1]} "
            f"does not match sparse_values_for_projection shape {sparse_values_for_projection.shape}"
        )

    # ------------------------------------------------------------
    # 3. Project raw moving membrane to fixed reference planes
    # ------------------------------------------------------------
    mem_proj = calFlowCrossResolution.project_coords_to_fixed_planes_gpu(
        coords_ref_xyk_xyz=phase_for_projection,
        ref_volume=ref_mem_adj_for_projection,       # used as reference canvas
        target_z_planes=fixed_target_z,
        values_xyk=mem_values_for_projection,        # values come from moving
        ref_volume_order="xyz",
        z_window=projection_z_window,
        downsample_xy=projection_downsample_xy,
        fill_value=projection_fill_value,
        return_numpy=True,
        output_order="zyx",
        xy_splat_mode="subpixel_footprint",
        xy_extra_radius=projection_xy_extra_radius,
    )

    # ------------------------------------------------------------
    # 4. Project raw moving sparse-cell to fixed reference planes
    # ------------------------------------------------------------
    sparse_proj = calFlowCrossResolution.project_coords_to_fixed_planes_gpu(
        coords_ref_xyk_xyz=phase_for_projection,
        ref_volume=F260517_ref_sparseCell,            # used as reference canvas
        target_z_planes=fixed_target_z,
        values_xyk=sparse_values_for_projection,      # values come from moving
        ref_volume_order="zyx",
        z_window=projection_z_window,
        downsample_xy=projection_downsample_xy,
        fill_value=projection_fill_value,
        return_numpy=True,
        output_order="zyx",
        xy_splat_mode="subpixel_footprint",
        xy_extra_radius=projection_xy_extra_radius,
    )

    coverage_rows = []

    # ------------------------------------------------------------
    # 5. Coverage diagnostics only
    # ------------------------------------------------------------
    if enable_coverage_diagnostics:
        coverage = project_converge_map_gpu(
            phase_new=phase_for_projection,
            ref_volume_for_shape=ref_mem_adj_for_projection,
            fixed_target_z=fixed_target_z,
            ref_volume_order="xyz",
            z_window=projection_z_window,
            downsample_xy=projection_downsample_xy,
            xy_extra_radius=projection_xy_extra_radius,
        )

        if hasattr(coverage, "get"):
            coverage = coverage.get()

        coverage = np.asarray(coverage, dtype=np.float32)

        if coverage.shape != mem_proj.shape:
            raise ValueError(
                f"coverage shape {coverage.shape} does not match projection shape {mem_proj.shape}. "
                "Please check project_converge_map_gpu output_order / downsample settings."
            )

        coverage_rows = summarize_coverage_only(
            frame_idx=frame_idx,
            coverage=coverage,
            coverage_threshold=coverage_threshold,
        )

    # ------------------------------------------------------------
    # 6. Optional hole filling from moving-derived projection only
    # ------------------------------------------------------------
    if enable_hole_filling:
        mem_proj = fill_holes_nearest_limited(
            mem_proj,
            fill_value=projection_fill_value,
            max_fill_distance=2.0,
        )

        sparse_proj = fill_holes_nearest_limited(
            sparse_proj,
            fill_value=projection_fill_value,
            max_fill_distance=1.5,
        )

    # ------------------------------------------------------------
    # 7. Save projected channels
    # ------------------------------------------------------------
    save_single_channel_ome_tiff(
        volume_zyx=mem_proj,
        out_dir=out_dirs["projected_mem"],
        frame_idx=frame_idx,
        label="F260517_projected_mem_from_moving",
    )

    save_single_channel_ome_tiff(
        volume_zyx=sparse_proj,
        out_dir=out_dirs["projected_sparseCell"],
        frame_idx=frame_idx,
        label="F260517_projected_sparseCell_from_moving",
    )

    del (
        mem_proj,
        sparse_proj,
        phase_for_projection,
        mem_values_for_projection,
        sparse_values_for_projection,
    )

    if "cleanup_gpu_memory" in globals():
        cleanup_gpu_memory()

    return coverage_rows


print("Helper functions defined.")
# Out:
# Helper functions defined.

# %%
# =========================================================
# Data loading
# =========================================================
reload(calFlowCrossResolution)
reload(prep)

F260517_mov, F260517_mov_desc = IO.readTiff(F260517_mov_path)
F260517_ref, F260517_ref_desc = IO.readTiff(F260517_ref_path)
print("Finish reading the dataset")

# =========================================================
# Split into 2 stacks
# =========================================================
F260517_ref_mem = F260517_ref[90:310, 1, :, :]
F260517_ref_sparseCell = F260517_ref[90:310, 0, :, :]

F260517_mov_mem: ndarray[tuple[int, ...], Any] = F260517_mov[:, :, 1, :, :]
F260517_mov_sparseCell: ndarray[tuple[int, ...], Any] = F260517_mov[:, :, 0, :, :]

print("F260517_ref_mem:", F260517_ref_mem.shape)          # (Zref, Y, X)
print("F260517_ref_sparseCell:", F260517_ref_sparseCell.shape)
print("F260517_mov_mem:", F260517_mov_mem.shape)          # (T, K, Y, X)
print("F260517_mov_sparseCell:", F260517_mov_sparseCell.shape)
print("Finish splitting the dataset")

# =========================================================
# Registration options
# =========================================================
option["r"] = 5
option["layer"] = 3
option["iter"] = 10
option["movRange"] = 5.0
option["tol"] = 1e-6
option["zRatio_HR"] = 1
option["wrong_region_enable"] = False

thresFactor = 5.0
maskRange = [5.0, 4000.0]
smoothPenalty_raw = 0.01

# =========================================================
# Find initial corresponding z slices
# =========================================================
z_init = calFlowCrossResolution.FindInitZ_stack_global_fixed_spacing(
    F260517_mov_mem[0].transpose(2, 1, 0),     # (X, Y, K)
    F260517_ref_mem.transpose(2, 1, 0),        # (X, Y, Zref)
    delta_ref_idx=10,
    use_gradient=False,
)

z_init = np.asarray(z_init, dtype=np.float32)
z_idx = np.rint(z_init).astype(np.int32)
z_idx = np.clip(z_idx, 0, F260517_ref_mem.shape[0] - 1)

K = z_init.shape[0]
T = F260517_mov_mem.shape[0]

x = np.arange(F260517_mov_mem[0].shape[2], dtype=np.float32)
y = np.arange(F260517_mov_mem[0].shape[1], dtype=np.float32)
k = np.arange(K, dtype=np.int32)

X_grid, Y_grid, K_grid = np.meshgrid(x, y, k, indexing="ij")

coords_xyz = np.empty(
    (F260517_mov_mem[0].shape[2], F260517_mov_mem[0].shape[1], K, 3),
    dtype=np.float32,
)
coords_xyz[..., 0] = X_grid
coords_xyz[..., 1] = Y_grid
coords_xyz[..., 2] = z_init[K_grid]

option["phase"] = coords_xyz

print("z_init:", z_init)
print("z_idx:", z_idx)
print("phase shape:", option["phase"].shape)
print("T (total frames):", T)

# =========================================================
# Quantile mapping percentiles
# =========================================================
percentiles = [
    0.1, 0.5, 1, 2, 5,
    10, 25, 50, 75, 90,
    95, 99, 99.5, 99.8,
]

# =========================================================
# Projection settings
# =========================================================
projection_z_window = 3.0
projection_downsample_xy = 1
projection_fill_value = -200.0
projection_xy_extra_radius = 0

surface_upsample_factor = 2
surface_mem_value_order = 1
surface_sparse_value_order = 0

enable_coverage_diagnostics = True
coverage_threshold = 0.0
enable_projection_hole_filling = False

# =========================================================
# Output directories
# =========================================================
base_out_dir = "/home/cyf/wbi/Virginia/registrated_data/f260517/f260517_0609/"

out_dirs = {
    "raw_moving_mem": os.path.join(base_out_dir, "raw_moving_mem"),
    "raw_moving_sparseCell": os.path.join(base_out_dir, "raw_moving_sparseCell"),
    "projected_mem": os.path.join(base_out_dir, "projected_mem"),
    "projected_sparseCell": os.path.join(base_out_dir, "projected_sparseCell"),
}

for _d in out_dirs.values():
    os.makedirs(_d, exist_ok=True)

diagnostic_dir = os.path.join(base_out_dir, "diagnostics")
os.makedirs(diagnostic_dir, exist_ok=True)

# =========================================================
# Reference update settings
# =========================================================
ref_update_every = 40

print("Initial setup done.")
# Out:
# Finish reading the dataset
# F260517_ref_mem: (220, 1500, 630)
# F260517_ref_sparseCell: (220, 1500, 630)
# F260517_mov_mem: (200, 20, 1500, 630)
# F260517_mov_sparseCell: (200, 20, 1500, 630)
# Finish splitting the dataset
# z_init: [ 20.  30.  40.  50.  60.  70.  80.  90. 100. 110. 120. 130. 140. 150.
#  160. 170. 180. 190. 200. 210.]
# z_idx: [ 20  30  40  50  60  70  80  90 100 110 120 130 140 150 160 170 180 190
#  200 210]
# phase shape: (630, 1500, 20, 3)
# T (total frames): 200
# Initial setup done.

# %%
# =========================================================
# Initial reference intensity mapping
# Use mean of raw frames 0,1,2,3,4 (beginning of video)
# =========================================================
init_calibration_frames = [0, 1, 2, 3, 4]
init_target_stack = np.mean(
    F260517_mov_mem[init_calibration_frames].astype(np.float32),
    axis=0,
)  # (K, Y, X)

print("Initial calibration frames:", init_calibration_frames)
print("Target stack shape:", init_target_stack.shape)

F260517_ref_mem_adj, src_q, tgt_q, used_percentiles = (
    update_reference_intensity_mapping_from_target_stack(
        F260517_ref_mem=F260517_ref_mem,
        target_stack_zyx=init_target_stack,
        z_idx=z_idx,
        option=option,
        thresFactor=thresFactor,
        maskRange=maskRange,
        smoothPenalty_raw=smoothPenalty_raw,
        percentiles=percentiles,
    )
)

print("[Init] Updated reference intensity mapping using mean of raw frames", init_calibration_frames)
print("src_q:", src_q)
print("tgt_q:", tgt_q)
# Out:
# Initial calibration frames: [0, 1, 2, 3, 4]
# Target stack shape: (20, 1500, 630)
# [Init] Updated reference intensity mapping using mean of raw frames [0, 1, 2, 3, 4]
# src_q: [ -188.     -156.     -140.     -120.      -87.      -53.       26.
#    314.     1897.     4546.     5872.     8854.    10194.    11971.002]
# tgt_q: [-118.4    -102.6     -94.6     -85.6     -71.      -56.4     -22.4
#   151.     1086.8    2605.2    3329.6    4888.2    5581.8    6505.8003]

# %%
# =========================================================
# Forward-only registration pipeline
#
#   1. Warmup: register frames 0→4, determine fixed_target_z
#   2. Forward: process 5→T, update ref every 40 frames
#      - Each ref update uses the most recent 5 registered frames
# =========================================================

# ------------------------------------------------------------
# Global state
# ------------------------------------------------------------
registered_mem_mapped = {}   # frame_idx -> mem_mapped_zyx (K, Y, X)
processed_count = 0
frames_since_ref_update = 0

target_z_pred_list = []
all_z_plane_stats = []
all_coverage_stats = []
records_warmup = []

fixed_target_z = None
target_z_combine_method = "median"
warmup_n = 5

# ------------------------------------------------------------
# Helper: update reference from recent registered frames
# ------------------------------------------------------------
def update_ref_from_recent_frames(frame_indices):
    """Calibrate reference intensity using the mean of the RAW MOVING frames at
    the given indices (consistent with the initial calibration). The raw moving
    data is what actually carries intensity drift over time; the warped-reference
    reconstruction in registered_mem_mapped does not, so it must not be the
    calibration target."""
    stacks = []
    for fi in frame_indices:
        if fi in registered_mem_mapped:
            stacks.append(F260517_mov_mem[fi].astype(np.float32, copy=False))
        else:
            print(f"  WARNING: frame {fi} not processed yet, skipping for ref update")

    if len(stacks) == 0:
        print("  WARNING: no cached frames available for ref update, skipping")
        return None, None, None

    target_stack = np.mean(np.stack(stacks, axis=0), axis=0).astype(np.float32, copy=False)

    ref_adj, sq, tq, up = update_reference_intensity_mapping_from_target_stack(
        F260517_ref_mem=F260517_ref_mem,
        target_stack_zyx=target_stack,
        z_idx=z_idx,
        option=option,
        thresFactor=thresFactor,
        maskRange=maskRange,
        smoothPenalty_raw=smoothPenalty_raw,
        percentiles=percentiles,
    )

    print(f"[RefUpdate] Calibrated from frames {frame_indices}, using {len(stacks)} stacks")
    print(f"  src_q: {sq}")
    print(f"  tgt_q: {tq}")

    return ref_adj, sq, tq

# ------------------------------------------------------------
# Helper: process a single frame
# ------------------------------------------------------------
def process_single_frame(i, ref_mem_adj):
    """Register one frame. Returns a dict with results."""
    raw_mem_zyx = F260517_mov_mem[i].astype(np.float32, copy=False)
    raw_sparse_zyx = F260517_mov_sparseCell[i].astype(np.float32, copy=False)

    mov_mem_i = raw_mem_zyx.transpose(2, 1, 0).astype(np.float32, copy=False)  # (X, Y, K)

    # Moving mask
    option["mask_mov"] = mask.getMask(mov_mem_i, thresFactor)
    option["mask_mov"] = mask.bwareafilt3_wei(option["mask_mov"], maskRange)

    # Registration
    phase_new, motion_current, mem_mapped = calFlowCrossResolution.getMotion_v2(
        mov_mem_i, ref_mem_adj, option, verbose=False,
    )

    # Convert from cupy if needed
    if hasattr(phase_new, "get"):
        phase_new = phase_new.get()
    if hasattr(motion_current, "get"):
        motion_current = motion_current.get()
    if hasattr(mem_mapped, "get"):
        mem_mapped = mem_mapped.get()

    phase_new = phase_new.astype(np.float32, copy=False)
    motion_current = motion_current.astype(np.float32, copy=False)
    mem_mapped = mem_mapped.astype(np.float32, copy=False)

    mem_err = float(np.mean(np.abs(mov_mem_i - mem_mapped)))

    # Cache mem_mapped (K, Y, X) for ref updates
    mem_mapped_zyx = mem_mapped.transpose(2, 1, 0).astype(np.float32, copy=False)

    # Estimate target z
    target_z_pred_i, df_z_i = estimate_projection_z_from_phase_simple(
        phase_new=phase_new,
        z_init=z_init,
        ref_shape=F260517_ref_mem.shape,
        ref_volume_order="zyx",
        method="trimmed_mean",
        trim_percentiles=(5, 95),
        frame_idx=i,
    )

    # Temporal initialization for next frame
    option["motion"] = (0.7 * motion_current).astype(np.float32, copy=False)

    return {
        "frame": i,
        "phase_new": phase_new,
        "motion_current": motion_current,
        "mem_mapped_zyx": mem_mapped_zyx,
        "mem_err": mem_err,
        "target_z_pred": target_z_pred_i,
        "df_z": df_z_i,
        "raw_mem_zyx": raw_mem_zyx,
        "raw_sparse_zyx": raw_sparse_zyx,
    }

# ------------------------------------------------------------
# Helper: project and save a frame result
# ------------------------------------------------------------
def project_and_save_result(result, ref_mem_adj_to_use):
    """Project a single frame result to fixed planes and save."""
    coverage_rows = project_and_save_single_frame_moving_derived(
        frame_idx=result["frame"],
        phase_new=result["phase_new"],
        fixed_target_z=fixed_target_z,
        ref_mem_adj_for_projection=ref_mem_adj_to_use,
        F260517_ref_sparseCell=F260517_ref_sparseCell,
        raw_mem_zyx=result["raw_mem_zyx"],
        raw_sparseCell_zyx=result["raw_sparse_zyx"],
        out_dirs=out_dirs,
        surface_upsample_factor=surface_upsample_factor,
        surface_mem_value_order=surface_mem_value_order,
        surface_sparse_value_order=surface_sparse_value_order,
        enable_coverage_diagnostics=enable_coverage_diagnostics,
        coverage_threshold=coverage_threshold,
        enable_hole_filling=enable_projection_hole_filling,
    )
    return coverage_rows

# ------------------------------------------------------------
# Initialize for first frame
# ------------------------------------------------------------
option["phase"] = coords_xyz.copy()
option.pop("motion", None)

# ============================================================
# Phase 1: Warmup — register first 5 frames, determine fixed_z
# ============================================================
print("=" * 80)
print("Phase 1: Warmup — registering frames 0→4")
print("=" * 80)

warmup_frames = [0, 1, 2, 3, 4]

for idx, i in enumerate(warmup_frames):
    # First warmup frame uses coords_xyz init; subsequent use temporal init
    if idx == 0:
        option["phase"] = coords_xyz.copy()
        option.pop("motion", None)

    result = process_single_frame(i, F260517_ref_mem_adj)

    registered_mem_mapped[i] = result["mem_mapped_zyx"]
    target_z_pred_list.append(result["target_z_pred"])
    all_z_plane_stats.append(result["df_z"])
    records_warmup.append(result)

    processed_count += 1
    frames_since_ref_update += 1

    print(f"[Warmup {idx+1}/{warmup_n}] Frame {i}: mem_err={result['mem_err']:.4f}")

# Determine fixed_target_z from warmup frames
fixed_target_z = robust_average_target_z(
    target_z_pred_list,
    method=target_z_combine_method,
    trim_percentiles=(10, 90),
)
bad = ~np.isfinite(fixed_target_z)
fixed_target_z[bad] = z_init[bad]

print("=" * 80)
print(f"[Projection] fixed_target_z determined from {len(warmup_frames)} warmup frames")
print("z_init:", z_init)
print("fixed_target_z:", fixed_target_z)
print("fixed_target_z - z_init:", fixed_target_z - z_init)
print("=" * 80)

# Flush warmup frames — project and save
for rec in records_warmup:
    coverage_rows = project_and_save_result(rec, F260517_ref_mem_adj)
    all_coverage_stats.extend(coverage_rows)
    print(f"[Projection] saved warmup frame {rec['frame']} | mem_err={rec['mem_err']:.4f}")

records_warmup.clear()

# ============================================================
# Phase 2: Forward 5→T, with ref update every 40 frames
# ============================================================
print("=" * 80)
print("Phase 2: Forward 5→T")
print("=" * 80)

for i in range(5, T):
    if i > 75:
        option["wrong_region_enable"] = True

    result = process_single_frame(i, F260517_ref_mem_adj)

    registered_mem_mapped[i] = result["mem_mapped_zyx"]
    all_z_plane_stats.append(result["df_z"])

    processed_count += 1
    frames_since_ref_update += 1

    # Project and save
    coverage_rows = project_and_save_result(result, F260517_ref_mem_adj)
    all_coverage_stats.extend(coverage_rows)

    print(f"[Fwd] Frame {i}: mem_err={result['mem_err']:.4f} | "
          f"processed={processed_count} | since_ref_update={frames_since_ref_update}")

    # Reference update every 40 frames — always use most recent 5 frames
    if frames_since_ref_update >= ref_update_every:
        calib_frames = sorted(registered_mem_mapped.keys())[-5:]
        print(f"\\n[RefUpdate] Updating reference mapping using recent frames {calib_frames}")

        new_ref, sq, tq = update_ref_from_recent_frames(calib_frames)
        if new_ref is not None:
            F260517_ref_mem_adj = new_ref
        frames_since_ref_update = 0

print("=" * 80)
print(f"Pipeline complete. Processed {processed_count} frames total.")
print(f"Frames in cache: {len(registered_mem_mapped)}")
print("=" * 80)
# Out:
# ================================================================================
# Phase 1: Warmup — registering frames 0→4
# ================================================================================
# [Warmup 1/5] Frame 0: mem_err=170.3118
# [Warmup 2/5] Frame 1: mem_err=170.6604
# [Warmup 3/5] Frame 2: mem_err=171.1361
# [Warmup 4/5] Frame 3: mem_err=170.6991
# [Warmup 5/5] Frame 4: mem_err=170.4696
# ================================================================================
# [Projection] fixed_target_z determined from 5 warmup frames
# z_init: [ 20.  30.  40.  50.  60.  70.  80.  90. 100. 110. 120. 130. 140. 150.
#  160. 170. 180. 190. 200. 210.]
# fixed_target_z: [ 19.863358  29.803465  40.24072   49.930035  60.665195  70.726494
#   81.0346    90.67564  100.340935 110.90576  121.02015  130.83269
#  140.49748  150.36488  160.74434  170.84966  180.75089  190.57024
#  200.55981  210.44498 ]
# fixed_target_z - z_init: [-0.13664246 -0.19653511  0.24071884 -0.06996536  0.66519547  0.72649384
#   1.0345993   0.6756363   0.34093475  0.9057617   1.0201492   0.8326874
#   0.4974823   0.36488342  0.744339    0.84965515  0.750885    0.5702362
#   0.55981445  0.4449768 ]
# ================================================================================
# [Supersurface] frame 0: upsample_factor=2
# [Coverage] frame 0: global_no_cov=0.0543, min_plane_no_cov=0.0051, median_plane_no_cov=0.0506, max_plane_no_cov=0.0991, worst_k=9
# [Projection] saved warmup frame 0 | mem_err=170.3118
# [Supersurface] frame 1: upsample_factor=2
# [Coverage] frame 1: global_no_cov=0.0706, min_plane_no_cov=0.0353, median_plane_no_cov=0.0691, max_plane_no_cov=0.1321, worst_k=1
# [Projection] saved warmup frame 1 | mem_err=170.6604
# [Supersurface] frame 2: upsample_factor=2
# [Coverage] frame 2: global_no_cov=0.0931, min_plane_no_cov=0.0323, median_plane_no_cov=0.0883, max_plane_no_cov=0.2417, worst_k=1
# [Projection] saved warmup frame 2 | mem_err=171.1361
# [Supersurface] frame 3: upsample_factor=2
# [Coverage] frame 3: global_no_cov=0.0724, min_plane_no_cov=0.0401, median_plane_no_cov=0.0677, max_plane_no_cov=0.1621, worst_k=0
# [Projection] saved warmup frame 3 | mem_err=170.6991
# [Supersurface] frame 4: upsample_factor=2
# [Coverage] frame 4: global_no_cov=0.0810, min_plane_no_cov=0.0339, median_plane_no_cov=0.0688, max_plane_no_cov=0.1819, worst_k=0
# [Projection] saved warmup frame 4 | mem_err=170.4696
# ================================================================================
# Phase 2: Forward 5→T
# ================================================================================
# [Supersurface] frame 5: upsample_factor=2
# [Coverage] frame 5: global_no_cov=0.0995, min_plane_no_cov=0.0331, median_plane_no_cov=0.0808, max_plane_no_cov=0.3042, worst_k=1
# [Fwd] Frame 5: mem_err=173.4286 | processed=6 | since_ref_update=6
# [Supersurface] frame 6: upsample_factor=2
# [Coverage] frame 6: global_no_cov=0.0978, min_plane_no_cov=0.0527, median_plane_no_cov=0.0881, max_plane_no_cov=0.2342, worst_k=1
# [Fwd] Frame 6: mem_err=170.8893 | processed=7 | since_ref_update=7
# [Supersurface] frame 7: upsample_factor=2
# [Coverage] frame 7: global_no_cov=0.0923, min_plane_no_cov=0.0344, median_plane_no_cov=0.0787, max_plane_no_cov=0.2367, worst_k=1
# [Fwd] Frame 7: mem_err=170.6640 | processed=8 | since_ref_update=8
# [Supersurface] frame 8: upsample_factor=2
# [Coverage] frame 8: global_no_cov=0.0904, min_plane_no_cov=0.0531, median_plane_no_cov=0.0866, max_plane_no_cov=0.2366, worst_k=2
# [Fwd] Frame 8: mem_err=170.6964 | processed=9 | since_ref_update=9
# [Supersurface] frame 9: upsample_factor=2
# [Coverage] frame 9: global_no_cov=0.0878, min_plane_no_cov=0.0166, median_plane_no_cov=0.0740, max_plane_no_cov=0.2361, worst_k=2
# [Fwd] Frame 9: mem_err=170.3321 | processed=10 | since_ref_update=10
# [Supersurface] frame 10: upsample_factor=2
# [Coverage] frame 10: global_no_cov=0.0891, min_plane_no_cov=0.0303, median_plane_no_cov=0.0835, max_plane_no_cov=0.2095, worst_k=2
# [Fwd] Frame 10: mem_err=170.3723 | processed=11 | since_ref_update=11
# [Supersurface] frame 11: upsample_factor=2
# [Coverage] frame 11: global_no_cov=0.1026, min_plane_no_cov=0.0510, median_plane_no_cov=0.0955, max_plane_no_cov=0.2506, worst_k=1
# [Fwd] Frame 11: mem_err=170.1949 | processed=12 | since_ref_update=12
# [Supersurface] frame 12: upsample_factor=2
# [Coverage] frame 12: global_no_cov=0.1030, min_plane_no_cov=0.0415, median_plane_no_cov=0.0955, max_plane_no_cov=0.2125, worst_k=1
# [Fwd] Frame 12: mem_err=169.9867 | processed=13 | since_ref_update=13
# [Supersurface] frame 13: upsample_factor=2
# [Coverage] frame 13: global_no_cov=0.1081, min_plane_no_cov=0.0437, median_plane_no_cov=0.0999, max_plane_no_cov=0.2515, worst_k=2
# [Fwd] Frame 13: mem_err=170.0231 | processed=14 | since_ref_update=14
# [Supersurface] frame 14: upsample_factor=2
# [Coverage] frame 14: global_no_cov=0.1106, min_plane_no_cov=0.0362, median_plane_no_cov=0.0980, max_plane_no_cov=0.2994, worst_k=2
# [Fwd] Frame 14: mem_err=169.9206 | processed=15 | since_ref_update=15
# [Supersurface] frame 15: upsample_factor=2
# [Coverage] frame 15: global_no_cov=0.1113, min_plane_no_cov=0.0544, median_plane_no_cov=0.0911, max_plane_no_cov=0.3407, worst_k=1
# [Fwd] Frame 15: mem_err=169.7081 | processed=16 | since_ref_update=16
# [Supersurface] frame 16: upsample_factor=2
# [Coverage] frame 16: global_no_cov=0.1067, min_plane_no_cov=0.0466, median_plane_no_cov=0.0902, max_plane_no_cov=0.2501, worst_k=3
# [Fwd] Frame 16: mem_err=169.8057 | processed=17 | since_ref_update=17
# [Supersurface] frame 17: upsample_factor=2
# [Coverage] frame 17: global_no_cov=0.1162, min_plane_no_cov=0.0401, median_plane_no_cov=0.1028, max_plane_no_cov=0.3072, worst_k=2
# [Fwd] Frame 17: mem_err=169.7345 | processed=18 | since_ref_update=18
# [Supersurface] frame 18: upsample_factor=2
# [Coverage] frame 18: global_no_cov=0.1074, min_plane_no_cov=0.0438, median_plane_no_cov=0.0840, max_plane_no_cov=0.3979, worst_k=1
# [Fwd] Frame 18: mem_err=169.5791 | processed=19 | since_ref_update=19
# [Supersurface] frame 19: upsample_factor=2
# [Coverage] frame 19: global_no_cov=0.1151, min_plane_no_cov=0.0433, median_plane_no_cov=0.1020, max_plane_no_cov=0.3041, worst_k=2
# [Fwd] Frame 19: mem_err=169.5085 | processed=20 | since_ref_update=20
# [Supersurface] frame 20: upsample_factor=2
# [Coverage] frame 20: global_no_cov=0.1268, min_plane_no_cov=0.0521, median_plane_no_cov=0.1140, max_plane_no_cov=0.3536, worst_k=1
# [Fwd] Frame 20: mem_err=169.9375 | processed=21 | since_ref_update=21
# [Supersurface] frame 21: upsample_factor=2
# [Coverage] frame 21: global_no_cov=0.1174, min_plane_no_cov=0.0520, median_plane_no_cov=0.1048, max_plane_no_cov=0.3328, worst_k=1
# [Fwd] Frame 21: mem_err=169.3927 | processed=22 | since_ref_update=22
# [Supersurface] frame 22: upsample_factor=2
# [Coverage] frame 22: global_no_cov=0.1298, min_plane_no_cov=0.0351, median_plane_no_cov=0.1143, max_plane_no_cov=0.2853, worst_k=1
# [Fwd] Frame 22: mem_err=170.3472 | processed=23 | since_ref_update=23
# [Supersurface] frame 23: upsample_factor=2
# [Coverage] frame 23: global_no_cov=0.1412, min_plane_no_cov=0.0606, median_plane_no_cov=0.1148, max_plane_no_cov=0.3618, worst_k=2
# [Fwd] Frame 23: mem_err=170.1908 | processed=24 | since_ref_update=24
# [Supersurface] frame 24: upsample_factor=2
# [Coverage] frame 24: global_no_cov=0.1436, min_plane_no_cov=0.0565, median_plane_no_cov=0.1269, max_plane_no_cov=0.3605, worst_k=2
# [Fwd] Frame 24: mem_err=169.8463 | processed=25 | since_ref_update=25
# [Supersurface] frame 25: upsample_factor=2
# [Coverage] frame 25: global_no_cov=0.1290, min_plane_no_cov=0.0315, median_plane_no_cov=0.1127, max_plane_no_cov=0.3309, worst_k=2
# [Fwd] Frame 25: mem_err=169.6694 | processed=26 | since_ref_update=26
# [Supersurface] frame 26: upsample_factor=2
# [Coverage] frame 26: global_no_cov=0.1315, min_plane_no_cov=0.0378, median_plane_no_cov=0.1122, max_plane_no_cov=0.3738, worst_k=2
# [Fwd] Frame 26: mem_err=169.7344 | processed=27 | since_ref_update=27
# [Supersurface] frame 27: upsample_factor=2
# [Coverage] frame 27: global_no_cov=0.1332, min_plane_no_cov=0.0596, median_plane_no_cov=0.1175, max_plane_no_cov=0.3815, worst_k=2
# [Fwd] Frame 27: mem_err=169.7002 | processed=28 | since_ref_update=28
# [Supersurface] frame 28: upsample_factor=2
# [Coverage] frame 28: global_no_cov=0.1083, min_plane_no_cov=0.0269, median_plane_no_cov=0.1009, max_plane_no_cov=0.2387, worst_k=4
# [Fwd] Frame 28: mem_err=169.2400 | processed=29 | since_ref_update=29
# [Supersurface] frame 29: upsample_factor=2
# [Coverage] frame 29: global_no_cov=0.1160, min_plane_no_cov=0.0578, median_plane_no_cov=0.1126, max_plane_no_cov=0.2952, worst_k=4
# [Fwd] Frame 29: mem_err=169.4492 | processed=30 | since_ref_update=30
# [Supersurface] frame 30: upsample_factor=2
# [Coverage] frame 30: global_no_cov=0.1056, min_plane_no_cov=0.0125, median_plane_no_cov=0.1134, max_plane_no_cov=0.1726, worst_k=2
# [Fwd] Frame 30: mem_err=169.4050 | processed=31 | since_ref_update=31
# [Supersurface] frame 31: upsample_factor=2
# [Coverage] frame 31: global_no_cov=0.1209, min_plane_no_cov=0.0300, median_plane_no_cov=0.1168, max_plane_no_cov=0.2248, worst_k=4
# [Fwd] Frame 31: mem_err=169.5831 | processed=32 | since_ref_update=32
# [Supersurface] frame 32: upsample_factor=2
# [Coverage] frame 32: global_no_cov=0.1267, min_plane_no_cov=0.0607, median_plane_no_cov=0.1135, max_plane_no_cov=0.2404, worst_k=2
# [Fwd] Frame 32: mem_err=169.4472 | processed=33 | since_ref_update=33
# [Supersurface] frame 33: upsample_factor=2
# [Coverage] frame 33: global_no_cov=0.1245, min_plane_no_cov=0.0453, median_plane_no_cov=0.1076, max_plane_no_cov=0.2919, worst_k=1
# [Fwd] Frame 33: mem_err=169.2374 | processed=34 | since_ref_update=34
# [Supersurface] frame 34: upsample_factor=2
# [Coverage] frame 34: global_no_cov=0.1316, min_plane_no_cov=0.0675, median_plane_no_cov=0.1141, max_plane_no_cov=0.3407, worst_k=4
# [Fwd] Frame 34: mem_err=169.2301 | processed=35 | since_ref_update=35
# [Supersurface] frame 35: upsample_factor=2
# [Coverage] frame 35: global_no_cov=0.1302, min_plane_no_cov=0.0694, median_plane_no_cov=0.1078, max_plane_no_cov=0.2597, worst_k=4
# [Fwd] Frame 35: mem_err=169.2103 | processed=36 | since_ref_update=36
# [Supersurface] frame 36: upsample_factor=2
# [Coverage] frame 36: global_no_cov=0.1176, min_plane_no_cov=0.0027, median_plane_no_cov=0.1152, max_plane_no_cov=0.2463, worst_k=1
# [Fwd] Frame 36: mem_err=168.9433 | processed=37 | since_ref_update=37
# [Supersurface] frame 37: upsample_factor=2
# [Coverage] frame 37: global_no_cov=0.1089, min_plane_no_cov=0.0097, median_plane_no_cov=0.1060, max_plane_no_cov=0.2375, worst_k=1
# [Fwd] Frame 37: mem_err=168.9414 | processed=38 | since_ref_update=38
# [Supersurface] frame 38: upsample_factor=2
# [Coverage] frame 38: global_no_cov=0.1376, min_plane_no_cov=0.0128, median_plane_no_cov=0.1560, max_plane_no_cov=0.2447, worst_k=1
# [Fwd] Frame 38: mem_err=169.2475 | processed=39 | since_ref_update=39
# [Supersurface] frame 39: upsample_factor=2
# [Coverage] frame 39: global_no_cov=0.1335, min_plane_no_cov=0.0375, median_plane_no_cov=0.1238, max_plane_no_cov=0.2775, worst_k=2
# [Fwd] Frame 39: mem_err=169.1046 | processed=40 | since_ref_update=40
# \n[RefUpdate] Updating reference mapping using recent frames [35, 36, 37, 38, 39]
# [RefUpdate] Calibrated from frames [35, 36, 37, 38, 39], using 5 stacks
#   src_q: [ -188.     -156.     -140.     -120.      -87.      -53.       26.
#    314.     1897.     4546.     5872.     8854.    10194.    11971.002]
#   tgt_q: [ -84.8003    -73.348854  -67.81677   -61.753887  -52.183647  -42.71138
#   -19.606472  142.53506  1059.8579   2549.2664   3241.8733   4764.187
#  5423.4814   6127.304   ]
# [Supersurface] frame 40: upsample_factor=2
# [Coverage] frame 40: global_no_cov=0.1570, min_plane_no_cov=0.0771, median_plane_no_cov=0.1251, max_plane_no_cov=0.4488, worst_k=2
# [Fwd] Frame 40: mem_err=167.4166 | processed=41 | since_ref_update=1
# [Supersurface] frame 41: upsample_factor=2
# [Coverage] frame 41: global_no_cov=0.1511, min_plane_no_cov=0.0704, median_plane_no_cov=0.1238, max_plane_no_cov=0.4975, worst_k=2
# [Fwd] Frame 41: mem_err=167.2053 | processed=42 | since_ref_update=2
# [Supersurface] frame 42: upsample_factor=2
# [Coverage] frame 42: global_no_cov=0.1663, min_plane_no_cov=0.0754, median_plane_no_cov=0.1349, max_plane_no_cov=0.4649, worst_k=2
# [Fwd] Frame 42: mem_err=167.5207 | processed=43 | since_ref_update=3
# [Supersurface] frame 43: upsample_factor=2
# [Coverage] frame 43: global_no_cov=0.1828, min_plane_no_cov=0.0953, median_plane_no_cov=0.1656, max_plane_no_cov=0.4162, worst_k=2
# [Fwd] Frame 43: mem_err=169.4960 | processed=44 | since_ref_update=4
# [Supersurface] frame 44: upsample_factor=2
# [Coverage] frame 44: global_no_cov=0.1747, min_plane_no_cov=0.0927, median_plane_no_cov=0.1508, max_plane_no_cov=0.4043, worst_k=2
# [Fwd] Frame 44: mem_err=168.5519 | processed=45 | since_ref_update=5
# [Supersurface] frame 45: upsample_factor=2
# [Coverage] frame 45: global_no_cov=0.1751, min_plane_no_cov=0.0704, median_plane_no_cov=0.1542, max_plane_no_cov=0.4767, worst_k=2
# [Fwd] Frame 45: mem_err=168.0833 | processed=46 | since_ref_update=6
# [Supersurface] frame 46: upsample_factor=2
# [Coverage] frame 46: global_no_cov=0.1642, min_plane_no_cov=0.0768, median_plane_no_cov=0.1395, max_plane_no_cov=0.4174, worst_k=2
# [Fwd] Frame 46: mem_err=168.1805 | processed=47 | since_ref_update=7
# [Supersurface] frame 47: upsample_factor=2
# [Coverage] frame 47: global_no_cov=0.1629, min_plane_no_cov=0.0542, median_plane_no_cov=0.1440, max_plane_no_cov=0.4410, worst_k=2
# [Fwd] Frame 47: mem_err=168.2385 | processed=48 | since_ref_update=8
# [Supersurface] frame 48: upsample_factor=2
# [Coverage] frame 48: global_no_cov=0.1700, min_plane_no_cov=0.0918, median_plane_no_cov=0.1549, max_plane_no_cov=0.4199, worst_k=2
# [Fwd] Frame 48: mem_err=167.7955 | processed=49 | since_ref_update=9
# [Supersurface] frame 49: upsample_factor=2
# [Coverage] frame 49: global_no_cov=0.1694, min_plane_no_cov=0.0574, median_plane_no_cov=0.1510, max_plane_no_cov=0.4382, worst_k=2
# [Fwd] Frame 49: mem_err=168.1222 | processed=50 | since_ref_update=10
# [Supersurface] frame 50: upsample_factor=2
# [Coverage] frame 50: global_no_cov=0.1828, min_plane_no_cov=0.0831, median_plane_no_cov=0.1547, max_plane_no_cov=0.4712, worst_k=2
# [Fwd] Frame 50: mem_err=167.9998 | processed=51 | since_ref_update=11
# [Supersurface] frame 51: upsample_factor=2
# [Coverage] frame 51: global_no_cov=0.1623, min_plane_no_cov=0.0835, median_plane_no_cov=0.1439, max_plane_no_cov=0.3856, worst_k=2
# [Fwd] Frame 51: mem_err=167.8061 | processed=52 | since_ref_update=12
# [Supersurface] frame 52: upsample_factor=2
# [Coverage] frame 52: global_no_cov=0.1713, min_plane_no_cov=0.0845, median_plane_no_cov=0.1417, max_plane_no_cov=0.4774, worst_k=2
# [Fwd] Frame 52: mem_err=167.7134 | processed=53 | since_ref_update=13
# [Supersurface] frame 53: upsample_factor=2
# [Coverage] frame 53: global_no_cov=0.1904, min_plane_no_cov=0.0895, median_plane_no_cov=0.1620, max_plane_no_cov=0.4755, worst_k=2
# [Fwd] Frame 53: mem_err=167.5397 | processed=54 | since_ref_update=14
# [Supersurface] frame 54: upsample_factor=2
# [Coverage] frame 54: global_no_cov=0.1789, min_plane_no_cov=0.0906, median_plane_no_cov=0.1662, max_plane_no_cov=0.4609, worst_k=2
# [Fwd] Frame 54: mem_err=167.4009 | processed=55 | since_ref_update=15
# [Supersurface] frame 55: upsample_factor=2
# [Coverage] frame 55: global_no_cov=0.1756, min_plane_no_cov=0.0893, median_plane_no_cov=0.1619, max_plane_no_cov=0.4199, worst_k=2
# [Fwd] Frame 55: mem_err=167.8040 | processed=56 | since_ref_update=16
# [Supersurface] frame 56: upsample_factor=2
# [Coverage] frame 56: global_no_cov=0.1983, min_plane_no_cov=0.0919, median_plane_no_cov=0.1719, max_plane_no_cov=0.4650, worst_k=2
# [Fwd] Frame 56: mem_err=167.7939 | processed=57 | since_ref_update=17
# [Supersurface] frame 57: upsample_factor=2
# [Coverage] frame 57: global_no_cov=0.1914, min_plane_no_cov=0.0917, median_plane_no_cov=0.1777, max_plane_no_cov=0.3790, worst_k=2
# [Fwd] Frame 57: mem_err=167.5134 | processed=58 | since_ref_update=18
# [Supersurface] frame 58: upsample_factor=2
# [Coverage] frame 58: global_no_cov=0.1957, min_plane_no_cov=0.0926, median_plane_no_cov=0.1857, max_plane_no_cov=0.4135, worst_k=2
# [Fwd] Frame 58: mem_err=167.4611 | processed=59 | since_ref_update=19
# [Supersurface] frame 59: upsample_factor=2
# [Coverage] frame 59: global_no_cov=0.1881, min_plane_no_cov=0.1127, median_plane_no_cov=0.1505, max_plane_no_cov=0.5273, worst_k=2
# [Fwd] Frame 59: mem_err=170.4406 | processed=60 | since_ref_update=20
# [Supersurface] frame 60: upsample_factor=2
# [Coverage] frame 60: global_no_cov=0.1839, min_plane_no_cov=0.1196, median_plane_no_cov=0.1661, max_plane_no_cov=0.3346, worst_k=2
# [Fwd] Frame 60: mem_err=169.5215 | processed=61 | since_ref_update=21
# [Supersurface] frame 61: upsample_factor=2
# [Coverage] frame 61: global_no_cov=0.1984, min_plane_no_cov=0.1082, median_plane_no_cov=0.1712, max_plane_no_cov=0.4431, worst_k=2
# [Fwd] Frame 61: mem_err=169.3430 | processed=62 | since_ref_update=22
# [Supersurface] frame 62: upsample_factor=2
# [Coverage] frame 62: global_no_cov=0.1810, min_plane_no_cov=0.0954, median_plane_no_cov=0.1696, max_plane_no_cov=0.3823, worst_k=2
# [Fwd] Frame 62: mem_err=168.8935 | processed=63 | since_ref_update=23
# [Supersurface] frame 63: upsample_factor=2
# [Coverage] frame 63: global_no_cov=0.1876, min_plane_no_cov=0.1057, median_plane_no_cov=0.1501, max_plane_no_cov=0.4802, worst_k=2
# [Fwd] Frame 63: mem_err=168.8396 | processed=64 | since_ref_update=24
# [Supersurface] frame 64: upsample_factor=2
# [Coverage] frame 64: global_no_cov=0.1885, min_plane_no_cov=0.1013, median_plane_no_cov=0.1636, max_plane_no_cov=0.5069, worst_k=2
# [Fwd] Frame 64: mem_err=168.9158 | processed=65 | since_ref_update=25
# [Supersurface] frame 65: upsample_factor=2
# [Coverage] frame 65: global_no_cov=0.1914, min_plane_no_cov=0.0971, median_plane_no_cov=0.1716, max_plane_no_cov=0.4362, worst_k=2
# [Fwd] Frame 65: mem_err=168.4609 | processed=66 | since_ref_update=26
# [Supersurface] frame 66: upsample_factor=2
# [Coverage] frame 66: global_no_cov=0.2041, min_plane_no_cov=0.1014, median_plane_no_cov=0.1926, max_plane_no_cov=0.3961, worst_k=2
# [Fwd] Frame 66: mem_err=168.5231 | processed=67 | since_ref_update=27
# [Supersurface] frame 67: upsample_factor=2
# [Coverage] frame 67: global_no_cov=0.2059, min_plane_no_cov=0.0343, median_plane_no_cov=0.2027, max_plane_no_cov=0.4463, worst_k=2
# [Fwd] Frame 67: mem_err=168.6969 | processed=68 | since_ref_update=28
# [Supersurface] frame 68: upsample_factor=2
# [Coverage] frame 68: global_no_cov=0.2032, min_plane_no_cov=0.1085, median_plane_no_cov=0.1706, max_plane_no_cov=0.4086, worst_k=2
# [Fwd] Frame 68: mem_err=168.6033 | processed=69 | since_ref_update=29
# [Supersurface] frame 69: upsample_factor=2
# [Coverage] frame 69: global_no_cov=0.2119, min_plane_no_cov=0.1035, median_plane_no_cov=0.1895, max_plane_no_cov=0.5069, worst_k=2
# [Fwd] Frame 69: mem_err=168.8951 | processed=70 | since_ref_update=30
# [Supersurface] frame 70: upsample_factor=2
# [Coverage] frame 70: global_no_cov=0.2145, min_plane_no_cov=0.0922, median_plane_no_cov=0.1890, max_plane_no_cov=0.5167, worst_k=2
# [Fwd] Frame 70: mem_err=168.6770 | processed=71 | since_ref_update=31
# [Supersurface] frame 71: upsample_factor=2
# [Coverage] frame 71: global_no_cov=0.2245, min_plane_no_cov=0.1083, median_plane_no_cov=0.2190, max_plane_no_cov=0.4245, worst_k=2
# [Fwd] Frame 71: mem_err=168.8476 | processed=72 | since_ref_update=32
# [Supersurface] frame 72: upsample_factor=2
# [Coverage] frame 72: global_no_cov=0.2304, min_plane_no_cov=0.0784, median_plane_no_cov=0.2039, max_plane_no_cov=0.4881, worst_k=2
# [Fwd] Frame 72: mem_err=168.5793 | processed=73 | since_ref_update=33
# [Supersurface] frame 73: upsample_factor=2
# [Coverage] frame 73: global_no_cov=0.2166, min_plane_no_cov=0.1080, median_plane_no_cov=0.2019, max_plane_no_cov=0.4098, worst_k=5
# [Fwd] Frame 73: mem_err=168.7195 | processed=74 | since_ref_update=34
# [Supersurface] frame 74: upsample_factor=2
# [Coverage] frame 74: global_no_cov=0.2119, min_plane_no_cov=0.1061, median_plane_no_cov=0.1934, max_plane_no_cov=0.4654, worst_k=2
# [Fwd] Frame 74: mem_err=169.9104 | processed=75 | since_ref_update=35
# [Supersurface] frame 75: upsample_factor=2
# [Coverage] frame 75: global_no_cov=0.2074, min_plane_no_cov=0.1280, median_plane_no_cov=0.1821, max_plane_no_cov=0.4551, worst_k=2
# [Fwd] Frame 75: mem_err=170.0370 | processed=76 | since_ref_update=36
# [Supersurface] frame 76: upsample_factor=2
# [Coverage] frame 76: global_no_cov=0.2077, min_plane_no_cov=0.0835, median_plane_no_cov=0.2098, max_plane_no_cov=0.3421, worst_k=4
# [Fwd] Frame 76: mem_err=169.4277 | processed=77 | since_ref_update=37
# [Supersurface] frame 77: upsample_factor=2
# [Coverage] frame 77: global_no_cov=0.2148, min_plane_no_cov=0.1331, median_plane_no_cov=0.1908, max_plane_no_cov=0.3353, worst_k=2
# [Fwd] Frame 77: mem_err=169.6540 | processed=78 | since_ref_update=38
# [Supersurface] frame 78: upsample_factor=2
# [Coverage] frame 78: global_no_cov=0.2175, min_plane_no_cov=0.1114, median_plane_no_cov=0.1981, max_plane_no_cov=0.4419, worst_k=2
# [Fwd] Frame 78: mem_err=171.1788 | processed=79 | since_ref_update=39
# [Supersurface] frame 79: upsample_factor=2
# [Coverage] frame 79: global_no_cov=0.2103, min_plane_no_cov=0.0968, median_plane_no_cov=0.1999, max_plane_no_cov=0.3849, worst_k=2
# [Fwd] Frame 79: mem_err=170.7942 | processed=80 | since_ref_update=40
# \n[RefUpdate] Updating reference mapping using recent frames [75, 76, 77, 78, 79]
# [RefUpdate] Calibrated from frames [75, 76, 77, 78, 79], using 5 stacks
#   src_q: [ -188.     -156.     -140.     -120.      -87.      -53.       26.
#    314.     1897.     4546.     5872.     8854.    10194.    11971.002]
#   tgt_q: [ -58.87514   -51.386944  -47.85531   -43.934612  -37.644245  -31.20403
#   -14.306225  135.19684  1030.2976   2474.1343   3114.9028   4444.245
#  4983.203    5578.502   ]
# [Supersurface] frame 80: upsample_factor=2
# [Coverage] frame 80: global_no_cov=0.2121, min_plane_no_cov=0.0884, median_plane_no_cov=0.1990, max_plane_no_cov=0.5106, worst_k=2
# [Fwd] Frame 80: mem_err=167.2454 | processed=81 | since_ref_update=1
# [Supersurface] frame 81: upsample_factor=2
# [Coverage] frame 81: global_no_cov=0.2199, min_plane_no_cov=0.1019, median_plane_no_cov=0.1933, max_plane_no_cov=0.4872, worst_k=0
# [Fwd] Frame 81: mem_err=167.1350 | processed=82 | since_ref_update=2
# [Supersurface] frame 82: upsample_factor=2
# [Coverage] frame 82: global_no_cov=0.2132, min_plane_no_cov=0.1003, median_plane_no_cov=0.2069, max_plane_no_cov=0.4587, worst_k=2
# [Fwd] Frame 82: mem_err=167.1587 | processed=83 | since_ref_update=3
# [Supersurface] frame 83: upsample_factor=2
# [Coverage] frame 83: global_no_cov=0.2204, min_plane_no_cov=0.1206, median_plane_no_cov=0.1951, max_plane_no_cov=0.5214, worst_k=2
# [Fwd] Frame 83: mem_err=167.0701 | processed=84 | since_ref_update=4
# [Supersurface] frame 84: upsample_factor=2
# [Coverage] frame 84: global_no_cov=0.2339, min_plane_no_cov=0.1295, median_plane_no_cov=0.2250, max_plane_no_cov=0.5278, worst_k=2
# [Fwd] Frame 84: mem_err=166.5993 | processed=85 | since_ref_update=5
# [Supersurface] frame 85: upsample_factor=2
# [Coverage] frame 85: global_no_cov=0.2213, min_plane_no_cov=0.1298, median_plane_no_cov=0.1952, max_plane_no_cov=0.5186, worst_k=2
# [Fwd] Frame 85: mem_err=167.1257 | processed=86 | since_ref_update=6
# [Supersurface] frame 86: upsample_factor=2
# [Coverage] frame 86: global_no_cov=0.2316, min_plane_no_cov=0.1129, median_plane_no_cov=0.2069, max_plane_no_cov=0.4335, worst_k=2
# [Fwd] Frame 86: mem_err=168.6056 | processed=87 | since_ref_update=7
# [Supersurface] frame 87: upsample_factor=2
# [Coverage] frame 87: global_no_cov=0.2113, min_plane_no_cov=0.1128, median_plane_no_cov=0.1932, max_plane_no_cov=0.3992, worst_k=2
# [Fwd] Frame 87: mem_err=167.8716 | processed=88 | since_ref_update=8
# [Supersurface] frame 88: upsample_factor=2
# [Coverage] frame 88: global_no_cov=0.2104, min_plane_no_cov=0.0939, median_plane_no_cov=0.2047, max_plane_no_cov=0.3704, worst_k=2
# [Fwd] Frame 88: mem_err=167.5927 | processed=89 | since_ref_update=9
# [Supersurface] frame 89: upsample_factor=2
# [Coverage] frame 89: global_no_cov=0.2404, min_plane_no_cov=0.1171, median_plane_no_cov=0.2115, max_plane_no_cov=0.5061, worst_k=0
# [Fwd] Frame 89: mem_err=167.2339 | processed=90 | since_ref_update=10
# [Supersurface] frame 90: upsample_factor=2
# [Coverage] frame 90: global_no_cov=0.2389, min_plane_no_cov=0.1382, median_plane_no_cov=0.2290, max_plane_no_cov=0.3832, worst_k=5
# [Fwd] Frame 90: mem_err=167.2907 | processed=91 | since_ref_update=11
# [Supersurface] frame 91: upsample_factor=2
# [Coverage] frame 91: global_no_cov=0.2425, min_plane_no_cov=0.1246, median_plane_no_cov=0.2349, max_plane_no_cov=0.4489, worst_k=2
# [Fwd] Frame 91: mem_err=167.3350 | processed=92 | since_ref_update=12
# [Supersurface] frame 92: upsample_factor=2
# [Coverage] frame 92: global_no_cov=0.2435, min_plane_no_cov=0.1399, median_plane_no_cov=0.2266, max_plane_no_cov=0.4625, worst_k=2
# [Fwd] Frame 92: mem_err=167.5050 | processed=93 | since_ref_update=13
# [Supersurface] frame 93: upsample_factor=2
# [Coverage] frame 93: global_no_cov=0.2513, min_plane_no_cov=0.1174, median_plane_no_cov=0.2405, max_plane_no_cov=0.5015, worst_k=2
# [Fwd] Frame 93: mem_err=167.0553 | processed=94 | since_ref_update=14
# [Supersurface] frame 94: upsample_factor=2
# [Coverage] frame 94: global_no_cov=0.2408, min_plane_no_cov=0.1178, median_plane_no_cov=0.2188, max_plane_no_cov=0.4857, worst_k=2
# [Fwd] Frame 94: mem_err=167.8118 | processed=95 | since_ref_update=15
# [Supersurface] frame 95: upsample_factor=2
# [Coverage] frame 95: global_no_cov=0.2444, min_plane_no_cov=0.1284, median_plane_no_cov=0.2284, max_plane_no_cov=0.4450, worst_k=2
# [Fwd] Frame 95: mem_err=168.0373 | processed=96 | since_ref_update=16
# [Supersurface] frame 96: upsample_factor=2
# [Coverage] frame 96: global_no_cov=0.2559, min_plane_no_cov=0.1441, median_plane_no_cov=0.2342, max_plane_no_cov=0.4476, worst_k=5
# [Fwd] Frame 96: mem_err=167.6876 | processed=97 | since_ref_update=17
# [Supersurface] frame 97: upsample_factor=2
# [Coverage] frame 97: global_no_cov=0.2554, min_plane_no_cov=0.1325, median_plane_no_cov=0.2278, max_plane_no_cov=0.4546, worst_k=5
# [Fwd] Frame 97: mem_err=167.8293 | processed=98 | since_ref_update=18
# [Supersurface] frame 98: upsample_factor=2
# [Coverage] frame 98: global_no_cov=0.2260, min_plane_no_cov=0.1119, median_plane_no_cov=0.2096, max_plane_no_cov=0.4507, worst_k=5
# [Fwd] Frame 98: mem_err=169.4115 | processed=99 | since_ref_update=19
# [Supersurface] frame 99: upsample_factor=2
# [Coverage] frame 99: global_no_cov=0.2419, min_plane_no_cov=0.1241, median_plane_no_cov=0.2255, max_plane_no_cov=0.4976, worst_k=2
# [Fwd] Frame 99: mem_err=168.8922 | processed=100 | since_ref_update=20
# [Supersurface] frame 100: upsample_factor=2
# [Coverage] frame 100: global_no_cov=0.2361, min_plane_no_cov=0.1266, median_plane_no_cov=0.2264, max_plane_no_cov=0.4380, worst_k=2
# [Fwd] Frame 100: mem_err=168.1437 | processed=101 | since_ref_update=21
# [Supersurface] frame 101: upsample_factor=2
# [Coverage] frame 101: global_no_cov=0.2376, min_plane_no_cov=0.1029, median_plane_no_cov=0.2260, max_plane_no_cov=0.4331, worst_k=5
# [Fwd] Frame 101: mem_err=168.4205 | processed=102 | since_ref_update=22
# [Supersurface] frame 102: upsample_factor=2
# [Coverage] frame 102: global_no_cov=0.2470, min_plane_no_cov=0.1069, median_plane_no_cov=0.2338, max_plane_no_cov=0.4841, worst_k=2
# [Fwd] Frame 102: mem_err=168.4464 | processed=103 | since_ref_update=23
# [Supersurface] frame 103: upsample_factor=2
# [Coverage] frame 103: global_no_cov=0.2574, min_plane_no_cov=0.1570, median_plane_no_cov=0.2431, max_plane_no_cov=0.4739, worst_k=2
# [Fwd] Frame 103: mem_err=168.2993 | processed=104 | since_ref_update=24
# [Supersurface] frame 104: upsample_factor=2
# [Coverage] frame 104: global_no_cov=0.2816, min_plane_no_cov=0.1644, median_plane_no_cov=0.2572, max_plane_no_cov=0.5726, worst_k=2
# [Fwd] Frame 104: mem_err=168.3798 | processed=105 | since_ref_update=25
# [Supersurface] frame 105: upsample_factor=2
# [Coverage] frame 105: global_no_cov=0.2873, min_plane_no_cov=0.1687, median_plane_no_cov=0.2575, max_plane_no_cov=0.5253, worst_k=2
# [Fwd] Frame 105: mem_err=168.4689 | processed=106 | since_ref_update=26
# [Supersurface] frame 106: upsample_factor=2
# [Coverage] frame 106: global_no_cov=0.2709, min_plane_no_cov=0.1407, median_plane_no_cov=0.2486, max_plane_no_cov=0.5423, worst_k=2
# [Fwd] Frame 106: mem_err=168.3105 | processed=107 | since_ref_update=27
# [Supersurface] frame 107: upsample_factor=2
# [Coverage] frame 107: global_no_cov=0.2773, min_plane_no_cov=0.1319, median_plane_no_cov=0.2627, max_plane_no_cov=0.5741, worst_k=2
# [Fwd] Frame 107: mem_err=168.1084 | processed=108 | since_ref_update=28
# [Supersurface] frame 108: upsample_factor=2
# [Coverage] frame 108: global_no_cov=0.2893, min_plane_no_cov=0.1655, median_plane_no_cov=0.2751, max_plane_no_cov=0.4895, worst_k=2
# [Fwd] Frame 108: mem_err=168.4481 | processed=109 | since_ref_update=29
# [Supersurface] frame 109: upsample_factor=2
# [Coverage] frame 109: global_no_cov=0.2783, min_plane_no_cov=0.1494, median_plane_no_cov=0.2566, max_plane_no_cov=0.5110, worst_k=2
# [Fwd] Frame 109: mem_err=168.6153 | processed=110 | since_ref_update=30
# [Supersurface] frame 110: upsample_factor=2
# [Coverage] frame 110: global_no_cov=0.2824, min_plane_no_cov=0.1513, median_plane_no_cov=0.2682, max_plane_no_cov=0.4839, worst_k=5
# [Fwd] Frame 110: mem_err=171.2869 | processed=111 | since_ref_update=31
# [Supersurface] frame 111: upsample_factor=2
# [Coverage] frame 111: global_no_cov=0.2638, min_plane_no_cov=0.1552, median_plane_no_cov=0.2578, max_plane_no_cov=0.4544, worst_k=5
# [Fwd] Frame 111: mem_err=170.2343 | processed=112 | since_ref_update=32
# [Supersurface] frame 112: upsample_factor=2
# [Coverage] frame 112: global_no_cov=0.2693, min_plane_no_cov=0.1066, median_plane_no_cov=0.2800, max_plane_no_cov=0.4256, worst_k=2
# [Fwd] Frame 112: mem_err=168.9659 | processed=113 | since_ref_update=33
# [Supersurface] frame 113: upsample_factor=2
# [Coverage] frame 113: global_no_cov=0.2669, min_plane_no_cov=0.1260, median_plane_no_cov=0.2463, max_plane_no_cov=0.4648, worst_k=5
# [Fwd] Frame 113: mem_err=169.0628 | processed=114 | since_ref_update=34
# [Supersurface] frame 114: upsample_factor=2
# [Coverage] frame 114: global_no_cov=0.2520, min_plane_no_cov=0.1352, median_plane_no_cov=0.2335, max_plane_no_cov=0.4475, worst_k=5
# [Fwd] Frame 114: mem_err=169.5941 | processed=115 | since_ref_update=35
# [Supersurface] frame 115: upsample_factor=2
# [Coverage] frame 115: global_no_cov=0.2660, min_plane_no_cov=0.1055, median_plane_no_cov=0.2564, max_plane_no_cov=0.4307, worst_k=5
# [Fwd] Frame 115: mem_err=170.0552 | processed=116 | since_ref_update=36
# [Supersurface] frame 116: upsample_factor=2
# [Coverage] frame 116: global_no_cov=0.2666, min_plane_no_cov=0.1458, median_plane_no_cov=0.2592, max_plane_no_cov=0.4380, worst_k=2
# [Fwd] Frame 116: mem_err=169.9874 | processed=117 | since_ref_update=37
# [Supersurface] frame 117: upsample_factor=2
# [Coverage] frame 117: global_no_cov=0.2742, min_plane_no_cov=0.0983, median_plane_no_cov=0.2665, max_plane_no_cov=0.4430, worst_k=5
# [Fwd] Frame 117: mem_err=170.0784 | processed=118 | since_ref_update=38
# [Supersurface] frame 118: upsample_factor=2
# [Coverage] frame 118: global_no_cov=0.2772, min_plane_no_cov=0.1243, median_plane_no_cov=0.2580, max_plane_no_cov=0.5124, worst_k=5
# [Fwd] Frame 118: mem_err=169.5658 | processed=119 | since_ref_update=39
# [Supersurface] frame 119: upsample_factor=2
# [Coverage] frame 119: global_no_cov=0.2780, min_plane_no_cov=0.1264, median_plane_no_cov=0.2485, max_plane_no_cov=0.4912, worst_k=5
# [Fwd] Frame 119: mem_err=169.1434 | processed=120 | since_ref_update=40
# \n[RefUpdate] Updating reference mapping using recent frames [115, 116, 117, 118, 119]
# [RefUpdate] Calibrated from frames [115, 116, 117, 118, 119], using 5 stacks
#   src_q: [ -188.     -156.     -140.     -120.      -87.      -53.       26.
#    314.     1897.     4546.     5872.     8854.    10194.    11971.002]
#   tgt_q: [ -48.520435  -41.999584  -38.881935  -35.42756   -29.919779  -24.18903
#    -8.495495  123.21313   990.3148   2364.492    2966.6467   4255.2896
#  4784.747    5312.1777  ]
# [Supersurface] frame 120: upsample_factor=2
# [Coverage] frame 120: global_no_cov=0.2976, min_plane_no_cov=0.1157, median_plane_no_cov=0.2923, max_plane_no_cov=0.4742, worst_k=14
# [Fwd] Frame 120: mem_err=166.2982 | processed=121 | since_ref_update=1
# [Supersurface] frame 121: upsample_factor=2
# [Coverage] frame 121: global_no_cov=0.3214, min_plane_no_cov=0.1914, median_plane_no_cov=0.3286, max_plane_no_cov=0.4935, worst_k=5
# [Fwd] Frame 121: mem_err=166.3527 | processed=122 | since_ref_update=2
# [Supersurface] frame 122: upsample_factor=2
# [Coverage] frame 122: global_no_cov=0.3191, min_plane_no_cov=0.1851, median_plane_no_cov=0.2914, max_plane_no_cov=0.5347, worst_k=19
# [Fwd] Frame 122: mem_err=166.6630 | processed=123 | since_ref_update=3
# [Supersurface] frame 123: upsample_factor=2
# [Coverage] frame 123: global_no_cov=0.3168, min_plane_no_cov=0.1921, median_plane_no_cov=0.2879, max_plane_no_cov=0.5819, worst_k=19
# [Fwd] Frame 123: mem_err=167.6862 | processed=124 | since_ref_update=4
# [Supersurface] frame 124: upsample_factor=2
# [Coverage] frame 124: global_no_cov=0.3206, min_plane_no_cov=0.1877, median_plane_no_cov=0.2714, max_plane_no_cov=0.5819, worst_k=19
# [Fwd] Frame 124: mem_err=166.9410 | processed=125 | since_ref_update=5
# [Supersurface] frame 125: upsample_factor=2
# [Coverage] frame 125: global_no_cov=0.3370, min_plane_no_cov=0.1630, median_plane_no_cov=0.3307, max_plane_no_cov=0.5557, worst_k=19
# [Fwd] Frame 125: mem_err=166.2569 | processed=126 | since_ref_update=6
# [Supersurface] frame 126: upsample_factor=2
# [Coverage] frame 126: global_no_cov=0.3393, min_plane_no_cov=0.1368, median_plane_no_cov=0.3098, max_plane_no_cov=0.6291, worst_k=19
# [Fwd] Frame 126: mem_err=165.8784 | processed=127 | since_ref_update=7
# [Supersurface] frame 127: upsample_factor=2
# [Coverage] frame 127: global_no_cov=0.3455, min_plane_no_cov=0.1433, median_plane_no_cov=0.3303, max_plane_no_cov=0.5984, worst_k=19
# [Fwd] Frame 127: mem_err=169.8159 | processed=128 | since_ref_update=8
# [Supersurface] frame 128: upsample_factor=2
# [Coverage] frame 128: global_no_cov=0.3483, min_plane_no_cov=0.1497, median_plane_no_cov=0.3349, max_plane_no_cov=0.6121, worst_k=19
# [Fwd] Frame 128: mem_err=168.4131 | processed=129 | since_ref_update=9
# [Supersurface] frame 129: upsample_factor=2
# [Coverage] frame 129: global_no_cov=0.3649, min_plane_no_cov=0.1507, median_plane_no_cov=0.3524, max_plane_no_cov=0.6528, worst_k=19
# [Fwd] Frame 129: mem_err=167.6009 | processed=130 | since_ref_update=10
# [Supersurface] frame 130: upsample_factor=2
# [Coverage] frame 130: global_no_cov=0.3742, min_plane_no_cov=0.1178, median_plane_no_cov=0.3789, max_plane_no_cov=0.6467, worst_k=19
# [Fwd] Frame 130: mem_err=167.5517 | processed=131 | since_ref_update=11
# [Supersurface] frame 131: upsample_factor=2
# [Coverage] frame 131: global_no_cov=0.4021, min_plane_no_cov=0.2180, median_plane_no_cov=0.4110, max_plane_no_cov=0.6584, worst_k=19
# [Fwd] Frame 131: mem_err=166.7607 | processed=132 | since_ref_update=12
# [Supersurface] frame 132: upsample_factor=2
# [Coverage] frame 132: global_no_cov=0.3993, min_plane_no_cov=0.1708, median_plane_no_cov=0.3884, max_plane_no_cov=0.6326, worst_k=19
# [Fwd] Frame 132: mem_err=166.3479 | processed=133 | since_ref_update=13
# [Supersurface] frame 133: upsample_factor=2
# [Coverage] frame 133: global_no_cov=0.3942, min_plane_no_cov=0.1224, median_plane_no_cov=0.3866, max_plane_no_cov=0.6121, worst_k=19
# [Fwd] Frame 133: mem_err=166.8540 | processed=134 | since_ref_update=14
# [Supersurface] frame 134: upsample_factor=2
# [Coverage] frame 134: global_no_cov=0.3718, min_plane_no_cov=0.1163, median_plane_no_cov=0.3639, max_plane_no_cov=0.5877, worst_k=19
# [Fwd] Frame 134: mem_err=166.9630 | processed=135 | since_ref_update=15
# [Supersurface] frame 135: upsample_factor=2
# [Coverage] frame 135: global_no_cov=0.3724, min_plane_no_cov=0.1259, median_plane_no_cov=0.3675, max_plane_no_cov=0.6208, worst_k=19
# [Fwd] Frame 135: mem_err=166.9030 | processed=136 | since_ref_update=16
# [Supersurface] frame 136: upsample_factor=2
# [Coverage] frame 136: global_no_cov=0.3693, min_plane_no_cov=0.1430, median_plane_no_cov=0.3664, max_plane_no_cov=0.6159, worst_k=19
# [Fwd] Frame 136: mem_err=166.9528 | processed=137 | since_ref_update=17
# [Supersurface] frame 137: upsample_factor=2
# [Coverage] frame 137: global_no_cov=0.3555, min_plane_no_cov=0.1395, median_plane_no_cov=0.3374, max_plane_no_cov=0.5878, worst_k=19
# [Fwd] Frame 137: mem_err=166.3620 | processed=138 | since_ref_update=18
# [Supersurface] frame 138: upsample_factor=2
# [Coverage] frame 138: global_no_cov=0.3720, min_plane_no_cov=0.1526, median_plane_no_cov=0.3676, max_plane_no_cov=0.6202, worst_k=19
# [Fwd] Frame 138: mem_err=166.8265 | processed=139 | since_ref_update=19
# [Supersurface] frame 139: upsample_factor=2
# [Coverage] frame 139: global_no_cov=0.3819, min_plane_no_cov=0.1918, median_plane_no_cov=0.3721, max_plane_no_cov=0.6105, worst_k=19
# [Fwd] Frame 139: mem_err=166.3935 | processed=140 | since_ref_update=20
# [Supersurface] frame 140: upsample_factor=2
# [Coverage] frame 140: global_no_cov=0.3804, min_plane_no_cov=0.1762, median_plane_no_cov=0.3577, max_plane_no_cov=0.6202, worst_k=19
# [Fwd] Frame 140: mem_err=167.0325 | processed=141 | since_ref_update=21
# [Supersurface] frame 141: upsample_factor=2
# [Coverage] frame 141: global_no_cov=0.3998, min_plane_no_cov=0.1411, median_plane_no_cov=0.4042, max_plane_no_cov=0.6472, worst_k=19
# [Fwd] Frame 141: mem_err=165.9106 | processed=142 | since_ref_update=22
# [Supersurface] frame 142: upsample_factor=2
# [Coverage] frame 142: global_no_cov=0.3933, min_plane_no_cov=0.1886, median_plane_no_cov=0.3941, max_plane_no_cov=0.6204, worst_k=19
# [Fwd] Frame 142: mem_err=167.4707 | processed=143 | since_ref_update=23
# [Supersurface] frame 143: upsample_factor=2
# [Coverage] frame 143: global_no_cov=0.3648, min_plane_no_cov=0.1331, median_plane_no_cov=0.3718, max_plane_no_cov=0.5874, worst_k=19
# [Fwd] Frame 143: mem_err=167.9897 | processed=144 | since_ref_update=24
# [Supersurface] frame 144: upsample_factor=2
# [Coverage] frame 144: global_no_cov=0.3522, min_plane_no_cov=0.1054, median_plane_no_cov=0.3413, max_plane_no_cov=0.5921, worst_k=19
# [Fwd] Frame 144: mem_err=167.4199 | processed=145 | since_ref_update=25
# [Supersurface] frame 145: upsample_factor=2
# [Coverage] frame 145: global_no_cov=0.3567, min_plane_no_cov=0.1315, median_plane_no_cov=0.3482, max_plane_no_cov=0.6115, worst_k=19
# [Fwd] Frame 145: mem_err=167.1746 | processed=146 | since_ref_update=26
# [Supersurface] frame 146: upsample_factor=2
# [Coverage] frame 146: global_no_cov=0.3630, min_plane_no_cov=0.2142, median_plane_no_cov=0.3632, max_plane_no_cov=0.5920, worst_k=19
# [Fwd] Frame 146: mem_err=169.0583 | processed=147 | since_ref_update=27
# [Supersurface] frame 147: upsample_factor=2
# [Coverage] frame 147: global_no_cov=0.3576, min_plane_no_cov=0.1060, median_plane_no_cov=0.3624, max_plane_no_cov=0.6002, worst_k=19
# [Fwd] Frame 147: mem_err=168.3210 | processed=148 | since_ref_update=28
# [Supersurface] frame 148: upsample_factor=2
# [Coverage] frame 148: global_no_cov=0.3657, min_plane_no_cov=0.1716, median_plane_no_cov=0.3626, max_plane_no_cov=0.6215, worst_k=19
# [Fwd] Frame 148: mem_err=168.4741 | processed=149 | since_ref_update=29
# [Supersurface] frame 149: upsample_factor=2
# [Coverage] frame 149: global_no_cov=0.3636, min_plane_no_cov=0.1450, median_plane_no_cov=0.3545, max_plane_no_cov=0.5915, worst_k=19
# [Fwd] Frame 149: mem_err=169.4749 | processed=150 | since_ref_update=30
# [Supersurface] frame 150: upsample_factor=2
# [Coverage] frame 150: global_no_cov=0.3677, min_plane_no_cov=0.1784, median_plane_no_cov=0.3625, max_plane_no_cov=0.6148, worst_k=19
# [Fwd] Frame 150: mem_err=170.1664 | processed=151 | since_ref_update=31
# [Supersurface] frame 151: upsample_factor=2
# [Coverage] frame 151: global_no_cov=0.3760, min_plane_no_cov=0.1320, median_plane_no_cov=0.3924, max_plane_no_cov=0.6231, worst_k=19
# [Fwd] Frame 151: mem_err=169.1957 | processed=152 | since_ref_update=32
# [Supersurface] frame 152: upsample_factor=2
# [Coverage] frame 152: global_no_cov=0.3775, min_plane_no_cov=0.1388, median_plane_no_cov=0.3528, max_plane_no_cov=0.6081, worst_k=19
# [Fwd] Frame 152: mem_err=169.0032 | processed=153 | since_ref_update=33
# [Supersurface] frame 153: upsample_factor=2
# [Coverage] frame 153: global_no_cov=0.4032, min_plane_no_cov=0.2095, median_plane_no_cov=0.4123, max_plane_no_cov=0.6368, worst_k=19
# [Fwd] Frame 153: mem_err=168.5778 | processed=154 | since_ref_update=34
# [Supersurface] frame 154: upsample_factor=2
# [Coverage] frame 154: global_no_cov=0.4191, min_plane_no_cov=0.1755, median_plane_no_cov=0.4286, max_plane_no_cov=0.6557, worst_k=19
# [Fwd] Frame 154: mem_err=168.4821 | processed=155 | since_ref_update=35
# [Supersurface] frame 155: upsample_factor=2
# [Coverage] frame 155: global_no_cov=0.3992, min_plane_no_cov=0.2211, median_plane_no_cov=0.3845, max_plane_no_cov=0.6160, worst_k=5
# [Fwd] Frame 155: mem_err=168.7551 | processed=156 | since_ref_update=36
# [Supersurface] frame 156: upsample_factor=2
# [Coverage] frame 156: global_no_cov=0.3819, min_plane_no_cov=0.1363, median_plane_no_cov=0.3976, max_plane_no_cov=0.5924, worst_k=19
# [Fwd] Frame 156: mem_err=168.8216 | processed=157 | since_ref_update=37
# [Supersurface] frame 157: upsample_factor=2
# [Coverage] frame 157: global_no_cov=0.3843, min_plane_no_cov=0.1406, median_plane_no_cov=0.3806, max_plane_no_cov=0.5907, worst_k=19
# [Fwd] Frame 157: mem_err=169.2364 | processed=158 | since_ref_update=38
# [Supersurface] frame 158: upsample_factor=2
# [Coverage] frame 158: global_no_cov=0.3887, min_plane_no_cov=0.2389, median_plane_no_cov=0.3809, max_plane_no_cov=0.6063, worst_k=19
# [Fwd] Frame 158: mem_err=168.9369 | processed=159 | since_ref_update=39
# [Supersurface] frame 159: upsample_factor=2
# [Coverage] frame 159: global_no_cov=0.3947, min_plane_no_cov=0.1459, median_plane_no_cov=0.3916, max_plane_no_cov=0.6136, worst_k=19
# [Fwd] Frame 159: mem_err=168.9521 | processed=160 | since_ref_update=40
# \n[RefUpdate] Updating reference mapping using recent frames [155, 156, 157, 158, 159]
# [RefUpdate] Calibrated from frames [155, 156, 157, 158, 159], using 5 stacks
#   src_q: [ -188.     -156.     -140.     -120.      -87.      -53.       26.
#    314.     1897.     4546.     5872.     8854.    10194.    11971.002]
#   tgt_q: [-3.9043968e+01 -3.3296738e+01 -3.0558279e+01 -2.7502590e+01
#  -2.2652891e+01 -1.7623407e+01 -4.0679736e+00  1.1477956e+02
#   9.5859247e+02  2.2641128e+03  2.8248423e+03  4.0393452e+03
#   4.5397534e+03  5.0429658e+03]
# [Supersurface] frame 160: upsample_factor=2
# [Coverage] frame 160: global_no_cov=0.4374, min_plane_no_cov=0.2693, median_plane_no_cov=0.4183, max_plane_no_cov=0.7204, worst_k=19
# [Fwd] Frame 160: mem_err=164.8705 | processed=161 | since_ref_update=1
# [Supersurface] frame 161: upsample_factor=2
# [Coverage] frame 161: global_no_cov=0.4445, min_plane_no_cov=0.2150, median_plane_no_cov=0.4219, max_plane_no_cov=0.7612, worst_k=19
# [Fwd] Frame 161: mem_err=164.9912 | processed=162 | since_ref_update=2
# [Supersurface] frame 162: upsample_factor=2
# [Coverage] frame 162: global_no_cov=0.4428, min_plane_no_cov=0.1315, median_plane_no_cov=0.4542, max_plane_no_cov=0.7304, worst_k=19
# [Fwd] Frame 162: mem_err=164.1633 | processed=163 | since_ref_update=3
# [Supersurface] frame 163: upsample_factor=2
# [Coverage] frame 163: global_no_cov=0.4538, min_plane_no_cov=0.1815, median_plane_no_cov=0.4654, max_plane_no_cov=0.7866, worst_k=19
# [Fwd] Frame 163: mem_err=164.4454 | processed=164 | since_ref_update=4
# [Supersurface] frame 164: upsample_factor=2
# [Coverage] frame 164: global_no_cov=0.4549, min_plane_no_cov=0.1830, median_plane_no_cov=0.4568, max_plane_no_cov=0.7472, worst_k=19
# [Fwd] Frame 164: mem_err=164.3472 | processed=165 | since_ref_update=5
# [Supersurface] frame 165: upsample_factor=2
# [Coverage] frame 165: global_no_cov=0.4583, min_plane_no_cov=0.1938, median_plane_no_cov=0.4632, max_plane_no_cov=0.7261, worst_k=19
# [Fwd] Frame 165: mem_err=164.4782 | processed=166 | since_ref_update=6
# [Supersurface] frame 166: upsample_factor=2
# [Coverage] frame 166: global_no_cov=0.4740, min_plane_no_cov=0.2194, median_plane_no_cov=0.4705, max_plane_no_cov=0.7791, worst_k=19
# [Fwd] Frame 166: mem_err=164.2060 | processed=167 | since_ref_update=7
# [Supersurface] frame 167: upsample_factor=2
# [Coverage] frame 167: global_no_cov=0.4610, min_plane_no_cov=0.1960, median_plane_no_cov=0.4581, max_plane_no_cov=0.7506, worst_k=19
# [Fwd] Frame 167: mem_err=164.4331 | processed=168 | since_ref_update=8
# [Supersurface] frame 168: upsample_factor=2
# [Coverage] frame 168: global_no_cov=0.4760, min_plane_no_cov=0.1677, median_plane_no_cov=0.4868, max_plane_no_cov=0.7604, worst_k=19
# [Fwd] Frame 168: mem_err=164.8772 | processed=169 | since_ref_update=9
# [Supersurface] frame 169: upsample_factor=2
# [Coverage] frame 169: global_no_cov=0.4689, min_plane_no_cov=0.1984, median_plane_no_cov=0.4689, max_plane_no_cov=0.7141, worst_k=19
# [Fwd] Frame 169: mem_err=164.6907 | processed=170 | since_ref_update=10
# [Supersurface] frame 170: upsample_factor=2
# [Coverage] frame 170: global_no_cov=0.4569, min_plane_no_cov=0.2004, median_plane_no_cov=0.4522, max_plane_no_cov=0.7736, worst_k=19
# [Fwd] Frame 170: mem_err=167.6666 | processed=171 | since_ref_update=11
# [Supersurface] frame 171: upsample_factor=2
# [Coverage] frame 171: global_no_cov=0.4407, min_plane_no_cov=0.1753, median_plane_no_cov=0.4447, max_plane_no_cov=0.7366, worst_k=19
# [Fwd] Frame 171: mem_err=165.3320 | processed=172 | since_ref_update=12
# [Supersurface] frame 172: upsample_factor=2
# [Coverage] frame 172: global_no_cov=0.4363, min_plane_no_cov=0.1944, median_plane_no_cov=0.4563, max_plane_no_cov=0.7174, worst_k=19
# [Fwd] Frame 172: mem_err=166.0431 | processed=173 | since_ref_update=13
# [Supersurface] frame 173: upsample_factor=2
# [Coverage] frame 173: global_no_cov=0.4529, min_plane_no_cov=0.2133, median_plane_no_cov=0.4552, max_plane_no_cov=0.7574, worst_k=19
# [Fwd] Frame 173: mem_err=165.9383 | processed=174 | since_ref_update=14
# [Supersurface] frame 174: upsample_factor=2
# [Coverage] frame 174: global_no_cov=0.4357, min_plane_no_cov=0.1746, median_plane_no_cov=0.4392, max_plane_no_cov=0.7685, worst_k=19
# [Fwd] Frame 174: mem_err=165.5634 | processed=175 | since_ref_update=15
# [Supersurface] frame 175: upsample_factor=2
# [Coverage] frame 175: global_no_cov=0.4504, min_plane_no_cov=0.1783, median_plane_no_cov=0.4516, max_plane_no_cov=0.7281, worst_k=19
# [Fwd] Frame 175: mem_err=165.7834 | processed=176 | since_ref_update=16
# [Supersurface] frame 176: upsample_factor=2
# [Coverage] frame 176: global_no_cov=0.4680, min_plane_no_cov=0.1499, median_plane_no_cov=0.4801, max_plane_no_cov=0.7561, worst_k=19
# [Fwd] Frame 176: mem_err=165.2870 | processed=177 | since_ref_update=17
# [Supersurface] frame 177: upsample_factor=2
# [Coverage] frame 177: global_no_cov=0.4622, min_plane_no_cov=0.2498, median_plane_no_cov=0.4468, max_plane_no_cov=0.7575, worst_k=19
# [Fwd] Frame 177: mem_err=165.8367 | processed=178 | since_ref_update=18
# [Supersurface] frame 178: upsample_factor=2
# [Coverage] frame 178: global_no_cov=0.4727, min_plane_no_cov=0.2690, median_plane_no_cov=0.4696, max_plane_no_cov=0.7617, worst_k=19
# [Fwd] Frame 178: mem_err=166.3060 | processed=179 | since_ref_update=19
# [Supersurface] frame 179: upsample_factor=2
# [Coverage] frame 179: global_no_cov=0.4938, min_plane_no_cov=0.2878, median_plane_no_cov=0.4876, max_plane_no_cov=0.7905, worst_k=19
# [Fwd] Frame 179: mem_err=165.0977 | processed=180 | since_ref_update=20
# [Supersurface] frame 180: upsample_factor=2
# [Coverage] frame 180: global_no_cov=0.4812, min_plane_no_cov=0.2058, median_plane_no_cov=0.5014, max_plane_no_cov=0.7794, worst_k=19
# [Fwd] Frame 180: mem_err=165.1589 | processed=181 | since_ref_update=21
# [Supersurface] frame 181: upsample_factor=2
# [Coverage] frame 181: global_no_cov=0.4752, min_plane_no_cov=0.2781, median_plane_no_cov=0.4739, max_plane_no_cov=0.7416, worst_k=19
# [Fwd] Frame 181: mem_err=166.4142 | processed=182 | since_ref_update=22
# [Supersurface] frame 182: upsample_factor=2
# [Coverage] frame 182: global_no_cov=0.4843, min_plane_no_cov=0.2981, median_plane_no_cov=0.4767, max_plane_no_cov=0.8007, worst_k=19
# [Fwd] Frame 182: mem_err=166.2373 | processed=183 | since_ref_update=23
# [Supersurface] frame 183: upsample_factor=2
# [Coverage] frame 183: global_no_cov=0.5152, min_plane_no_cov=0.3010, median_plane_no_cov=0.5297, max_plane_no_cov=0.7922, worst_k=19
# [Fwd] Frame 183: mem_err=165.3746 | processed=184 | since_ref_update=24
# [Supersurface] frame 184: upsample_factor=2
# [Coverage] frame 184: global_no_cov=0.5075, min_plane_no_cov=0.2974, median_plane_no_cov=0.5105, max_plane_no_cov=0.7863, worst_k=19
# [Fwd] Frame 184: mem_err=165.4112 | processed=185 | since_ref_update=25
# [Supersurface] frame 185: upsample_factor=2
# [Coverage] frame 185: global_no_cov=0.5157, min_plane_no_cov=0.3446, median_plane_no_cov=0.5074, max_plane_no_cov=0.7854, worst_k=19
# [Fwd] Frame 185: mem_err=165.6232 | processed=186 | since_ref_update=26
# [Supersurface] frame 186: upsample_factor=2
# [Coverage] frame 186: global_no_cov=0.4704, min_plane_no_cov=0.2607, median_plane_no_cov=0.4462, max_plane_no_cov=0.7682, worst_k=19
# [Fwd] Frame 186: mem_err=167.6398 | processed=187 | since_ref_update=27
# [Supersurface] frame 187: upsample_factor=2
# [Coverage] frame 187: global_no_cov=0.4795, min_plane_no_cov=0.3090, median_plane_no_cov=0.4879, max_plane_no_cov=0.7171, worst_k=19
# [Fwd] Frame 187: mem_err=166.6223 | processed=188 | since_ref_update=28
# [Supersurface] frame 188: upsample_factor=2
# [Coverage] frame 188: global_no_cov=0.4735, min_plane_no_cov=0.2956, median_plane_no_cov=0.4781, max_plane_no_cov=0.7667, worst_k=19
# [Fwd] Frame 188: mem_err=166.2794 | processed=189 | since_ref_update=29
# [Supersurface] frame 189: upsample_factor=2
# [Coverage] frame 189: global_no_cov=0.4689, min_plane_no_cov=0.2837, median_plane_no_cov=0.4942, max_plane_no_cov=0.7470, worst_k=19
# [Fwd] Frame 189: mem_err=166.3980 | processed=190 | since_ref_update=30
# [Supersurface] frame 190: upsample_factor=2
# [Coverage] frame 190: global_no_cov=0.4664, min_plane_no_cov=0.3054, median_plane_no_cov=0.4845, max_plane_no_cov=0.7226, worst_k=19
# [Fwd] Frame 190: mem_err=166.7529 | processed=191 | since_ref_update=31
# [Supersurface] frame 191: upsample_factor=2
# [Coverage] frame 191: global_no_cov=0.4582, min_plane_no_cov=0.2841, median_plane_no_cov=0.4568, max_plane_no_cov=0.7100, worst_k=19
# [Fwd] Frame 191: mem_err=166.8556 | processed=192 | since_ref_update=32
# [Supersurface] frame 192: upsample_factor=2
# [Coverage] frame 192: global_no_cov=0.4487, min_plane_no_cov=0.2868, median_plane_no_cov=0.4376, max_plane_no_cov=0.6997, worst_k=19
# [Fwd] Frame 192: mem_err=166.5107 | processed=193 | since_ref_update=33
# [Supersurface] frame 193: upsample_factor=2
# [Coverage] frame 193: global_no_cov=0.4438, min_plane_no_cov=0.2303, median_plane_no_cov=0.4245, max_plane_no_cov=0.7267, worst_k=19
# [Fwd] Frame 193: mem_err=166.6886 | processed=194 | since_ref_update=34
# [Supersurface] frame 194: upsample_factor=2
# [Coverage] frame 194: global_no_cov=0.4496, min_plane_no_cov=0.2010, median_plane_no_cov=0.4635, max_plane_no_cov=0.7141, worst_k=19
# [Fwd] Frame 194: mem_err=166.4003 | processed=195 | since_ref_update=35
# [Supersurface] frame 195: upsample_factor=2
# [Coverage] frame 195: global_no_cov=0.4775, min_plane_no_cov=0.2637, median_plane_no_cov=0.4851, max_plane_no_cov=0.7046, worst_k=19
# [Fwd] Frame 195: mem_err=166.3582 | processed=196 | since_ref_update=36
# [Supersurface] frame 196: upsample_factor=2
# [Coverage] frame 196: global_no_cov=0.4614, min_plane_no_cov=0.2630, median_plane_no_cov=0.4724, max_plane_no_cov=0.7031, worst_k=19
# [Fwd] Frame 196: mem_err=166.1031 | processed=197 | since_ref_update=37
# [Supersurface] frame 197: upsample_factor=2
# [Coverage] frame 197: global_no_cov=0.4702, min_plane_no_cov=0.3019, median_plane_no_cov=0.4623, max_plane_no_cov=0.7469, worst_k=19
# [Fwd] Frame 197: mem_err=167.2637 | processed=198 | since_ref_update=38
# [Supersurface] frame 198: upsample_factor=2
# [Coverage] frame 198: global_no_cov=0.4553, min_plane_no_cov=0.3067, median_plane_no_cov=0.4599, max_plane_no_cov=0.7468, worst_k=19
# [Fwd] Frame 198: mem_err=166.6730 | processed=199 | since_ref_update=39
# [Supersurface] frame 199: upsample_factor=2
# [Coverage] frame 199: global_no_cov=0.4673, min_plane_no_cov=0.2702, median_plane_no_cov=0.4642, max_plane_no_cov=0.7541, worst_k=19
# [Fwd] Frame 199: mem_err=166.3323 | processed=200 | since_ref_update=40
# \n[RefUpdate] Updating reference mapping using recent frames [195, 196, 197, 198, 199]
# [RefUpdate] Calibrated from frames [195, 196, 197, 198, 199], using 5 stacks
#   src_q: [ -188.     -156.     -140.     -120.      -87.      -53.       26.
#    314.     1897.     4546.     5872.     8854.    10194.    11971.002]
#   tgt_q: [-2.9495703e+01 -2.4513306e+01 -2.2190210e+01 -1.9637455e+01
#  -1.5572120e+01 -1.1347466e+01  3.0745078e-02  1.1041936e+02
#   9.3428528e+02  2.1873062e+03  2.7077903e+03  3.7726382e+03
#   4.2041416e+03  4.6596245e+03]
# ================================================================================
# Pipeline complete. Processed 200 frames total.
# Frames in cache: 200
# ================================================================================

# %%
# =========================================================
# Save diagnostics
# =========================================================
if len(all_z_plane_stats) > 0:
    z_plane_stats_all = pd.concat(all_z_plane_stats, ignore_index=True)
    z_plane_stats_all.to_csv(
        os.path.join(diagnostic_dir, "z_plane_pred_stats.csv"),
        index=False,
    )
    print(f"Saved z_plane_stats: {len(z_plane_stats_all)} rows")

if len(all_coverage_stats) > 0:
    coverage_stats_all = pd.DataFrame(all_coverage_stats)
    coverage_stats_all.to_csv(
        os.path.join(diagnostic_dir, "coverage_stats.csv"),
        index=False,
    )
    print(f"Saved coverage_stats: {len(coverage_stats_all)} rows")

if fixed_target_z is not None:
    np.save(
        os.path.join(diagnostic_dir, "fixed_target_z.npy"),
        fixed_target_z.astype(np.float32),
    )
    print("Saved fixed_target_z.npy")

# Save processing order
np.save(
    os.path.join(diagnostic_dir, "processing_order.npy"),
    np.array(sorted(registered_mem_mapped.keys()), dtype=np.int32),
)

print("Diagnostics saved.")
print("Done.")
